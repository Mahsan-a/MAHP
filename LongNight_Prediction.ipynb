# %%
# %run ./src.ipynb
# Out:
# 2025-04-11 20:23:27.460541: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-11 20:23:27.474293: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-11 20:23:27.478313: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# learning_rate=2e-4
# Resampled
# checkpoint
# monitor='val_loss'
# 10 split
# batch 32

# %matplotlib inline

matrix_shape0 = 288
dailyshape = 327
individualshape = 324
folder_name = "/home/__/results/holdoutResultsFull/LongNight"

configure_gpu()

# Perform K-Fold Cross-Validation with Transfer Learning
source_results, target_results = cross_validation_holdout_analysis(label_name="hypo_long_night",num_splits=10, num_epochs=60,batch_s=32, num_patience=15, monitored='val_loss',threshold=0.36)

gc.collect()
# Save results for comparison
saved_results = "/home/__/results/holdoutResultsFull/LongNight/source_results.npy"
np.save(saved_results, source_results)
# Save results for comparison
saved_results = "/home/__/results/holdoutResultsFull/LongNight/target_results.npy"
np.save(saved_results, target_results)
# Out:
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 1...
# Class weights:  {0: 0.6092927280489541, 1: 2.7874348958333335}
# Epoch 1/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - AUC: 0.5144 - accuracy: 0.5010 - loss: 3.5060 - val_AUC: 0.5238 - val_accuracy: 0.8102 - val_loss: 2.8868 - learning_rate: 2.0000e-04
# Epoch 2/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - AUC: 0.4942 - accuracy: 0.4928 - loss: 2.9601 - val_AUC: 0.4595 - val_accuracy: 0.5996 - val_loss: 2.7187 - learning_rate: 2.0000e-04
# Epoch 3/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - AUC: 0.5169 - accuracy: 0.4889 - loss: 2.7293 - val_AUC: 0.5189 - val_accuracy: 0.8045 - val_loss: 2.4867 - learning_rate: 2.0000e-04
# Epoch 4/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.5155 - accuracy: 0.5166 - loss: 2.5044 - val_AUC: 0.5366 - val_accuracy: 0.6485 - val_loss: 2.3159 - learning_rate: 2.0000e-04
# Epoch 5/60
# ...
