# %%
# %run ./src.ipynb
# Out:
# 2025-04-11 20:24:21.651671: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-11 20:24:21.665329: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-11 20:24:21.669354: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# learning_rate=2e-4
# Resampled
# checkpoint
# monitor='val_loss'
# 8 split
# batch 32

# %matplotlib inline

matrix_shape0 = 288
dailyshape = 327
individualshape = 324
folder_name = "/home/__/results/holdoutResultsFull/NightMorning1"
configure_gpu()
# Perform K-Fold Cross-Validation with Transfer Learning
source_results, target_results = cross_validation_holdout_analysis(label_name="hypo_night_morning",num_splits=8, num_epochs=60,batch_s=32, num_patience=15, monitored='val_loss',threshold=0.5)

gc.collect()
# Save results for comparison
saved_results = "/home/__/results/holdoutResultsFull/NightMorning1/source_results.npy"
np.save(saved_results, source_results)
# Save results for comparison
saved_results = "/home/__/results/holdoutResultsFull/NightMorning1/target_results.npy"
np.save(saved_results, target_results)
# Out:
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 1...
# Class weights:  {0: 0.6775597404652635, 1: 1.9079768270944741}
# Epoch 1/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 26s 58ms/step - AUC: 0.5060 - accuracy: 0.5213 - loss: 3.4864 - val_AUC: 0.5081 - val_accuracy: 0.5038 - val_loss: 2.8951 - learning_rate: 2.0000e-04
# Epoch 2/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - AUC: 0.5072 - accuracy: 0.5064 - loss: 2.8966 - val_AUC: 0.5093 - val_accuracy: 0.6147 - val_loss: 2.6428 - learning_rate: 2.0000e-04
# Epoch 3/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.5108 - accuracy: 0.5261 - loss: 2.6258 - val_AUC: 0.5077 - val_accuracy: 0.4680 - val_loss: 2.4221 - learning_rate: 2.0000e-04
# Epoch 4/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - AUC: 0.5490 - accuracy: 0.5177 - loss: 2.3658 - val_AUC: 0.6665 - val_accuracy: 0.6278 - val_loss: 2.1606 - learning_rate: 2.0000e-04
# Epoch 5/60
# ...
