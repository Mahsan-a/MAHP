# %%
import pandas as pd
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import datetime
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib import pyplot
from scipy import stats
from scipy.stats import spearmanr
from scipy.signal import find_peaks, detrend
import pywt
from numpy import arange, array, linspace, loadtxt, log2, logspace, mean, polyfit
from numpy import zeros, pi, sin, cos, arctan2, sqrt, real, imag, conj, tile
from numpy import round, interp, diff, unique, where
from pandas import DataFrame, date_range
import matplotlib.dates as mdates
from matplotlib import pyplot
from scipy.stats import pearsonr, mannwhitneyu, kruskal, norm, wasserstein_distance
from sklearn.linear_model import LinearRegression, Ridge, LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GroupKFold, GroupShuffleSplit
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,f1_score, recall_score, precision_score,roc_auc_score, roc_curve, auc,accuracy_score,classification_report,confusion_matrix
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import shuffle
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
import keras.backend as K
from keras.utils import Sequence

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from collections import defaultdict, Counter


import tensorflow as tf
import keras
from keras.models import Model, load_model
from keras import layers
# from tensorflow.keras.models import Model, load_model
from keras.layers import GlobalAveragePooling2D,GlobalMaxPooling2D,Concatenate,Input,Dropout, Conv2D, MaxPooling2D, Flatten,Multiply,Attention,Dense,concatenate,Masking,BatchNormalization, Reshape
from keras.models import Sequential
from keras.optimizers import Adam
from keras.applications import DenseNet121
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, History
history = History()

import pickle
import joblib
import dill
import json
from collections import defaultdict
from scipy.signal import savgol_filter
import gc

import warnings
warnings.filterwarnings('ignore')
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
import sys
sys.stderr = open(os.devnull, 'w')
# Out:
# 2025-04-03 07:34:58.987392: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-03 07:34:59.001596: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-03 07:34:59.005627: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1743665946.060878 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.078297 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.091598 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.092047 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.093018 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.094731 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.104802 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.105652 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.106234 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.107341 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.107612 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.108082 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.113816 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.114012 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.116402 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.116860 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.138768 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.138772 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.142485 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.143721 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.149964 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.150237 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.151526 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.154468 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.154913 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.155078 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.166290 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.166343 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.168010 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.168108 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.170054 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.170134 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.183773 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.184825 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.191838 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.192512 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.194106 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.194160 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.194847 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.195868 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.195941 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.196643 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.196780 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.197271 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.197397 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.197997 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.198292 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.198622 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.198891 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.199193 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.199625 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.199935 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.200444 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.200601 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.201392 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.201467 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.202897 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.202960 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.211567 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.218419 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.221246 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.229223 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.230885 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.233109 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.248454 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.248642 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.252015 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.254624 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.255370 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.257578 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.262221 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.262416 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.264561 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.269256 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.269467 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.272342 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.277023 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.278226 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.734230 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.735192 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.736308 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.739702 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.740905 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.741092 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.741285 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.741490 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.741699 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.741916 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.742130 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.742331 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.742550 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.742768 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.742995 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.743214 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.743434 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.747627 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.749120 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.750697 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.752202 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.753305 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.753542 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.753760 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.753980 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.754193 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.755449 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.755695 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.755920 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.756145 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.757137 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.757362 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.757661 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.757899 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.758130 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.759853 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.760089 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.760407 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.827631 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.828057 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.828302 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.828534 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.828767 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.828999 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.829233 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.829476 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.829715 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.829956 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.830197 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.830438 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.830685 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.830933 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.831181 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.831436 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.831686 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.831934 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.832182 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.832431 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.832686 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.832954 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.833207 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.833479 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.833747 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.834019 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.834299 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.834574 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.835154 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.836425 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.836818 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.837157 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.837499 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.837954 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.838283 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.838622 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.838964 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.840527 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.841166 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.841759 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.856612 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.858241 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.859693 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.861253 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.862748 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.862940 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.863126 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.863310 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.863498 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.863685 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.863871 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.864059 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.864251 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.864444 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.864636 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.864826 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.865018 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.865213 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.865401 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.865594 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.865786 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.865976 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.866169 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.866363 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.866557 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.866758 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.866949 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.867145 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.867337 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.867531 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.867724 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.867922 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.868401 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.868608 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.869684 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.870716 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.870922 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.871124 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.871332 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665946.871539 4041153 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.150226 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.150623 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.152658 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.154449 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.156324 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.157582 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.158694 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.159945 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.164520 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.169541 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.171305 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.172385 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.173792 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.177498 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.177713 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.177931 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.178147 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.178366 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.180036 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.181633 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.183708 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.184897 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.185143 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.185371 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.185590 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.185803 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.186233 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.186466 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.186698 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.186927 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.187302 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.188500 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.190835 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.192423 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.193734 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.195813 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.196933 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.198173 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.270339 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.271895 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.273932 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.279305 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.280580 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.281755 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.283053 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.287103 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.287350 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.287598 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.287849 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.288096 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.288355 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.288606 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.288862 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.289116 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.290713 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.292604 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.297276 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.298478 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.299645 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.300983 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.307001 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.308792 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.309985 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.312744 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.314828 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.316020 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.317554 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.321266 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.321845 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.322124 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.324014 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.325836 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.327389 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.328120 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.328408 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.329505 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.330162 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.330462 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.338383 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.339682 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.341840 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.344816 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.346479 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.348536 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.353713 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.358615 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.361517 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.362727 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.364335 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.366113 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.366899 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.367100 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.367300 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.367500 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.367697 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.367893 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.368083 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.368277 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.368474 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.368665 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.368857 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.369048 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.369242 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.369437 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.369634 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.369833 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.370035 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.370235 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.370430 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.370623 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.370815 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.371006 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.372616 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.376918 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.379100 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.380198 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.382660 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665947.385946 4041158 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.567136 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.568807 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.573218 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.574975 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.577758 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.582925 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.587843 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.589310 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.589543 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.591005 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.591336 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.591570 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.592063 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.592655 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.593961 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.596712 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.599123 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.600332 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.602718 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.607680 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.609191 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.610793 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.612297 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.612544 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.612802 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.613149 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.614645 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.616765 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.618507 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.628975 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.633032 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.634337 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.635621 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.636775 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.674085 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.674316 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.674528 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.674749 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.678696 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.680365 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.681829 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.682519 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.682759 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.684712 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.685011 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.685237 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.687117 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.693923 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.696326 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.698289 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.698595 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.698870 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.699587 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.699956 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.701462 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.704139 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.706444 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.707724 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.726559 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.731092 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.731606 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.731947 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.732223 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.732506 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.732867 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.733151 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.733640 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.733931 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.734869 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.737368 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.739097 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.740628 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.741929 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.745512 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.747147 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.747577 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.749185 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.750804 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743665948.752644 4041157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# W0000 00:00:1743669449.438977 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.441805 4041144 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.442008 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.443384 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.445391 4041144 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.446726 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.449568 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.452631 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.458596 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.462138 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.466073 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.468756 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.474938 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669449.477812 4041147 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.656806 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.661046 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.665455 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.665830 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.666389 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.666716 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.667049 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.667637 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.667976 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.668601 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.668955 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.669296 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.669628 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.669936 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.670536 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.671801 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.672986 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.674120 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.674721 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.675065 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.676587 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.677864 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.678440 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.678785 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.680750 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.684377 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.689559 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.693920 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.700122 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.701518 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.703207 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.704834 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.705204 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.705604 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.705998 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.706352 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.706728 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.707123 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.707539 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.719314 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.722269 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.727979 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.734167 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.736545 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.737378 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.737564 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.737751 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.738195 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.738381 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.738566 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.738751 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.738934 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.740151 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.741450 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.742599 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.743787 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.744947 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.745136 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.745331 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.745530 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.745732 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.745926 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.746119 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.747098 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.747285 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.750282 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.751427 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.752525 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.753548 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.755451 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.763827 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.769234 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.771432 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.772932 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.774360 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.775775 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.775972 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.776212 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.776416 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.783563 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.784152 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.784330 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.784504 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.784682 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.784870 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.785047 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.785224 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.785397 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.786338 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.789775 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.793565 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.798122 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.803520 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.808946 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.809147 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.809627 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.809807 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.809979 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.810151 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.810583 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.810758 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.810927 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.811096 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.811268 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.811444 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.811878 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.812052 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.812226 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.812406 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.812847 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.813032 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.813217 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.813404 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.813599 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.813792 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.813981 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.814728 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.815954 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743669451.817084 4041149 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2,1"

# %%
# Configure GPUs to grow memory as needed
def configure_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

def plot_training_history(folds_val_loss, folds_val_auc, folds_val_acc, folder):
    # Determine max_epochs as the minimum length of the folds minus 10
    max_epochs = min(len(fold) for fold in folds_val_auc) - 10

    # Initialize arrays to store average and standard deviation for each epoch
    avg_loss = np.zeros(max_epochs)
    std_loss = np.zeros(max_epochs)
    avg_auc = np.zeros(max_epochs)
    std_auc = np.zeros(max_epochs)
    avg_acc = np.zeros(max_epochs)
    std_acc = np.zeros(max_epochs)

    # Compute average and standard deviation for each epoch
    for epoch in range(max_epochs):
        losses = []
        aucs = []
        accuracies = []
        for fold_loss, fold_auc, fold_acc in zip(folds_val_loss, folds_val_auc, folds_val_acc):
            if epoch < len(fold_loss):
                losses.append(fold_loss[epoch])
            if epoch < len(fold_auc):
                aucs.append(fold_auc[epoch])
            if epoch < len(fold_acc):
                accuracies.append(fold_acc[epoch])
        if losses:
            avg_loss[epoch] = np.mean(losses)
            std_loss[epoch] = np.std(losses)
        if aucs:
            avg_auc[epoch] = np.mean(aucs)
            std_auc[epoch] = np.std(aucs)
        if accuracies:
            avg_acc[epoch] = np.mean(accuracies)
            std_acc[epoch] = np.std(accuracies)

    # Adjusted x-axis range: 1 to 3*max_epochs + 1 with step size of 3
    epochs_range = range(1, 3 * max_epochs + 1, 3)

    # Plot average loss, AUC, and accuracy
    plt.figure(figsize=(12, 5))

    # Loss plot
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, avg_loss, color='blue', label='Validation Loss')
    plt.fill_between(epochs_range, 
                     avg_loss - std_loss,
                     avg_loss + std_loss,
                     color='blue', alpha=0.2)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.title('Validation Loss per Epoch', fontsize=14)
    plt.legend(fontsize=10)

    # AUC plot
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, avg_auc, color='blue', label='Validation AUC')
    plt.fill_between(epochs_range, 
                     avg_auc - std_auc,
                     avg_auc + std_auc,
                     color='blue', alpha=0.2)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('AUC', fontsize=12)
    plt.title('Validation AUC per Epoch', fontsize=14)
    plt.legend(fontsize=10)

    # Accuracy plot
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, avg_acc, color='blue', label='Validation Accuracy')
    plt.fill_between(epochs_range, 
                     avg_acc - std_acc,
                     avg_acc + std_acc,
                     color='blue', alpha=0.2)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.title('Validation Accuracy per Epoch', fontsize=14)
    plt.legend(fontsize=10)

    # Tight layout and save
    plt.tight_layout()
    plot_path = os.path.join(folder, 'loss_auc_accuracy_plot.png')
    plt.savefig(plot_path)
    print(f"Plot saved at: {plot_path}")
    plt.show()

def apply_smote_resampling_cgm(X_matrices, y, matrix_shape0=288):
    smote = SMOTE(random_state=42)

    # Combine all inputs into a single 2D array for SMOTE
    X_combined = np.hstack([
        X_matrices.reshape(-1, matrix_shape0 * 288*3)
    ])

    # Apply SMOTE to the combined array and the target
    X_resampled_combined, y_resampled = smote.fit_resample(X_combined, y)

    # Extract the resampled components
    X_matrices_resampled = X_resampled_combined[:, :matrix_shape0 * 288*3].reshape(-1, matrix_shape0, 288, 3)

    return (X_matrices_resampled, 
            y_resampled)
def apply_smote_resampling(X_matrices, X_features_daily, X_features_individual, y, matrix_shape0=288):
    smote = SMOTE(random_state=42)

    # Combine all inputs into a single 2D array for SMOTE
    X_combined = np.hstack([
        X_matrices.reshape(-1, matrix_shape0 * 288*3),
        X_features_daily,
        X_features_individual
    ])

    # Apply SMOTE to the combined array and the target
    X_resampled_combined, y_resampled = smote.fit_resample(X_combined, y)

    # Extract the resampled components
    X_matrices_resampled = X_resampled_combined[:, :matrix_shape0 * 288*3].reshape(-1, matrix_shape0, 288, 3)
    start = matrix_shape0 * 288*3
    X_features_daily_resampled = X_resampled_combined[:, start:start + X_features_daily.shape[1]]
    start += X_features_daily.shape[1]
    X_features_individual_resampled = X_resampled_combined[:, start:]
    
    return X_matrices_resampled, X_features_daily_resampled, X_features_individual_resampled, y_resampled

class SMOTEDataGenerator(Sequence):
    def __init__(self, X_matrices, X_daily, X_individual, y, batch_size=16, matrix_shape0=288):
        self.X_matrices = X_matrices
        self.X_daily = X_daily
        self.X_individual = X_individual
        self.y = y
        self.batch_size = batch_size
        self.matrix_shape0 = matrix_shape0
        self.smote = SMOTE(random_state=42)

    def __len__(self):
        return int(np.ceil(len(self.y) / self.batch_size))

    def __getitem__(self, idx):
        start = idx * self.batch_size
        end = start + self.batch_size
        
        # Extract batch
        X_matrices_batch = self.X_matrices[start:end]
        X_daily_batch = self.X_daily[start:end]
        X_individual_batch = self.X_individual[start:end]
        y_batch = self.y[start:end]
        
        # Flatten for SMOTE
        X_combined = np.hstack([
            X_matrices_batch.reshape(-1, self.matrix_shape0 * 288 * 3),
            X_daily_batch,
            X_individual_batch
        ])

        # Apply SMOTE to this batch
        X_resampled, y_resampled = self.smote.fit_resample(X_combined, y_batch)

        # Reshape back
        X_matrices_resampled = X_resampled[:, :self.matrix_shape0 * 288 * 3].reshape(-1, self.matrix_shape0, 288, 3)
        start = self.matrix_shape0 * 288 * 3
        X_daily_resampled = X_resampled[:, start:start + X_daily_batch.shape[1]]
        start += X_daily_batch.shape[1]
        X_individual_resampled = X_resampled[:, start:]

        return [X_matrices_resampled, X_daily_resampled, X_individual_resampled], y_resampled

def initialize_results():
    return {
        "fold_model": [], "train_acc": [], "val_acc": [], "accuracy_scores": [], "recall_scores": [],"precision_scores": [], "f1_scores": [], "roc_auc_scores": [], "specificity_scores": [],
        "mae": [], "mse": [],"fold_train_loss": [],"fold_train_auc": [],"fold_train_acc": [],"fold_val_loss": [],"fold_val_auc": [],"fold_val_acc": [],
        "conf_matrix": [], "class_report": [],"train_loss": [],"train_acc": [],"val_loss": [],"val_acc": [],
    }

def prepare_datasets(file_path):
    """
    Loads and processes dataset from the given file path.
    Filters data, extracts relevant features and labels, applies normalization, 
    and prepares input matrices for analysis.

    Args:
        file_path (str): Path to the dataset file.

    Returns:
        tuple: matrices, daily_features, individual_features, labels, participant_ids
    """
    
    # Load data
    with open(file_path, "rb") as f:
        data_dict = dill.load(f)
    
    # Filter data
    if len(data_dict)>350:
        filtered_data_dict = {}
        for participant_id, days_data in data_dict.items():
            filtered_days_data = [day_data for current_date, day_data in days_data.items()
                                  if (day_data['len_original_cgm'] > 252 and 
                                      np.sum(day_data['CGM_stats_daily_original'].isna()).sum() < 1)]
            if filtered_days_data:
                filtered_data_dict[participant_id] = filtered_days_data
    else:
        filtered_data_dict = data_dict
    
    del data_dict
    # Initialize data structures
    participant_ids = []
    X_features_individual, X_features_daily = [], []
    X_matrices_power = []
    labels = { 
        "hypo_early_night": [], "hypo_night": [], "hypo_long_night": [],
        "hypo_night_morning": [], "hyper_day": [], "hypo_late_night": [],
        "hyper_night": [], "hyper_early_night": [], "hypo_morning": [],
        "hypo_day": []
    }
    
    # Process data
    for participant_id, days_data in filtered_data_dict.items():
        participant_ids.extend([participant_id] * len(days_data))
        for day_data in days_data:
            X_matrices_power.append(day_data['full_matrix_cgm_power'])
            X_features_daily.append(np.concatenate([
                day_data['CGM_stats_daily_original'],
                day_data['Basal_stats_daily'],
                day_data['Carbs_stats_daily'],
                day_data['HR_stats_daily']], axis=1))
            X_features_individual.append(np.concatenate([
                [[day_data['A1c']]],
                [[day_data['Weight']]],
                [[day_data['Height']]],
                day_data['CGM_stats_participant'],
                day_data['Basal_stats_participant'],
                day_data['HR_stats_participant']], axis=1))
            
            for label in labels.keys():
                labels[label].append(day_data['next_day_cgm_labels_original'][label])
    
    # Convert lists to numpy arrays
    participant_ids = np.array(participant_ids)
    X_matrices_power = np.array(X_matrices_power)
    X_features_daily = np.array(X_features_daily)
    X_features_individual = np.array(X_features_individual)
    for key in labels:
        labels[key] = np.array(labels[key], dtype=np.float32)
    
    # Standardization function
    def standard_scale(data):
        scaler = StandardScaler()
        data[np.isinf(data)] = np.nan  # Replace infinities with NaN
        return scaler.fit_transform(data.reshape(-1, data.shape[-1]))
    
    # Apply standardization
    individual_features = standard_scale(X_features_individual)
    daily_features = standard_scale(X_features_daily)
    
    # # Function to check for NaNs
    # def check_nans(arr, name):
    #     print(f"{name}: {np.isnan(arr).sum()} NaNs found, shape: {arr.shape}")
    
    # print('Checking for NaNs in the data...')
    # check_nans(X_matrices_power, "X_matrices_power")
    # check_nans(individual_features, "X_features_individual_scaled")
    # check_nans(daily_features, "X_features_daily_scaled")
    # for key in labels:
    #     check_nans(labels[key], f"y_label {key}")
    
    del filtered_data_dict, X_features_daily, X_features_individual    
    # Manual standard scaling for matrices
    def manual_standard_scaling(matrix):
        return matrix / np.nanstd(matrix)
    
    matrices = np.zeros_like(X_matrices_power)
    for i in range(X_matrices_power.shape[0]):
        for channel in range(3):  # Assuming 3 channels in last dimension
            matrices[i, :, :, channel] = manual_standard_scaling(X_matrices_power[i, :, :, channel])
    
    del X_matrices_power
    gc.collect()
    
    return matrices, daily_features, individual_features, labels, participant_ids
 
# Attention mechanism
def attention_block(x):
    attention = Conv2D(32, kernel_size=(1, 1), activation='relu')(x)
    attention = BatchNormalization()(attention)
    attention = GlobalMaxPooling2D()(attention)
    attention = Dense(x.shape[-1], activation='sigmoid')(attention)
    attention = Reshape((1, 1, x.shape[-1]))(attention)
    attention = Multiply()([x, attention])
    return attention

def create_model_1d():
    # Define the CNN Model
    input_matrix = Input(shape=(matrix_shape0, 288, 3), name='input_matrix')
    
    conv1 = Conv2D(32, kernel_size=(5, 5), strides=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(input_matrix)
    conv1 = BatchNormalization()(conv1)
    conv1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv1 = attention_block(conv1)  # Add attention here

    conv2 = Conv2D(64, kernel_size=(3, 3), dilation_rate=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # Convolution Block 3 with Spatial Pyramid Pooling
    conv3 = Conv2D(128, kernel_size=(3, 3), strides=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(conv2)
    conv3 = BatchNormalization()(conv3)
    conv3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Flatten and concatenate with feature vectors
    flat = Flatten()(conv3)
    dense_flat = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(flat)
    attention_flat = Dense(1024, activation='softmax')(dense_flat)
    attention_flat = Multiply()([dense_flat, attention_flat])

    densed_fully = Dense(256, activation='relu')(attention_flat)
    densed_fully = Dropout(0.5)(densed_fully)
    
    fc_additional = Dense(128, activation='relu')(densed_fully)
    output = Dense(1, activation='sigmoid', dtype='float32')(fc_additional)
    model = Model(inputs=input_matrix, outputs=output)
    model.compile(optimizer=Adam(learning_rate=5e-5), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
    return model
def create_model_cgm():
    # Define the CNN Model
    input_matrix = Input(shape=(matrix_shape0, 288, 3), name='input_matrix')
    input_features_daily = Input(shape=(dailyshape,), name='input_features_daily')
    input_features_individual = Input(shape=(individualshape,), name='input_features_individual')

    conv1 = Conv2D(32, kernel_size=(5, 5), strides=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(input_matrix)
    conv1 = BatchNormalization()(conv1)
    conv1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv1 = attention_block(conv1)  # Add attention here

    conv2 = Conv2D(64, kernel_size=(3, 3), dilation_rate=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # Convolution Block 3 with Spatial Pyramid Pooling
    conv3 = Conv2D(128, kernel_size=(3, 3), strides=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(conv2)
    conv3 = BatchNormalization()(conv3)
    conv3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Flatten and concatenate with feature vectors
    flat = Flatten()(conv3)
    dense_flat = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(flat)
    attention_flat = Dense(1024, activation='softmax')(dense_flat)
    attention_flat = Multiply()([dense_flat, attention_flat])

    densed_fully = Dense(512, activation='relu')(attention_flat)
    densed_fully = Dropout(0.5)(densed_fully)
    dense_daily = Dense(128, activation='relu')(input_features_daily)
    dense_individual = Dense(128, activation='relu')(input_features_individual)
    
    # Combine feature inputs
    concat_features = concatenate([dense_daily, dense_individual])
    # Cross-Attention mechanism to extract relevant parts of both feature vectors
    attention_weights = Dense(256, activation='softmax')(concat_features)
    attention_features = Multiply()([concat_features, attention_weights])
    # Combine all inputs
    concat_all = concatenate([densed_fully, attention_features])
    
    fc_combined = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(concat_all)
    fc_combined = Dropout(0.6)(fc_combined)

    attention_fc_combined = Dense(256, activation='relu')(fc_combined)
    attention_fc_combined = Dropout(0.7)(attention_fc_combined)
    
    fc_additional = Dense(128, activation='relu')(attention_fc_combined)
    output = Dense(1, activation='sigmoid')(fc_additional)
    # Define the model
    model = Model(inputs=[input_matrix, input_features_daily, input_features_individual], outputs=output)
    model.compile(optimizer=Adam(learning_rate=2e-4), loss='binary_crossentropy', metrics=['accuracy','AUC'])
    return model
def create_model_mask():
    # Define the CNN Model
    input_matrix = Input(shape=(matrix_shape0, 288, 3), name='input_matrix')
    input_features_daily = Input(shape=(dailyshape,), name='input_features_daily')
    input_features_individual = Input(shape=(individualshape,), name='input_features_individual')
    input_mask_daily = Input(shape=(dailyshape,), name='input_mask_daily')
    input_mask_individual = Input(shape=(individualshape,), name='input_mask_individual')
    
    conv1 = Conv2D(32, kernel_size=(5, 5), strides=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(input_matrix)
    conv1 = BatchNormalization()(conv1)
    conv1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv1 = attention_block(conv1)  # Add attention here

    conv2 = Conv2D(64, kernel_size=(3, 3), dilation_rate=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # Convolution Block 3 with Spatial Pyramid Pooling
    conv3 = Conv2D(128, kernel_size=(3, 3), strides=(2, 2), activation='relu', kernel_regularizer=l2(0.001))(conv2)
    conv3 = BatchNormalization()(conv3)
    conv3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Flatten and concatenate with feature vectors
    flat = Flatten()(conv3)
    dense_flat = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(flat)

    densed_fully = Dense(512, activation='relu')(dense_flat)
    densed_fully = Dropout(0.5)(densed_fully)

    # Masked dense layers for the daily features
    masked_daily = Multiply()([input_features_daily, input_mask_daily])  # Apply mask to daily features
    dense_daily = Dense(128, activation='relu')(masked_daily)
    
    # Masked dense layers for the individual features
    masked_individual = Multiply()([input_features_individual, input_mask_individual])
    dense_individual = Dense(128, activation='relu')(masked_individual)
    
    # Combine feature inputs
    concat_features = concatenate([dense_daily, dense_individual])
    
    # Cross-Attention mechanism to extract relevant parts of both feature vectors
    attention_weights = Dense(256, activation='softmax')(concat_features)
    attention_features = Multiply()([concat_features, attention_weights])
    
    # Combine all inputs
    concat_all = concatenate([densed_fully, attention_features])
    
    fc_combined = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(concat_all)
    fc_combined = Dropout(0.6)(fc_combined)

    attention_fc_combined = Dense(256, activation='relu')(fc_combined)
    attention_fc_combined = Dropout(0.7)(attention_fc_combined)
    
    fc_additional = Dense(128, activation='relu')(attention_fc_combined)
    output = Dense(1, activation='sigmoid', dtype='float32')(fc_additional)
    model = Model(inputs=[input_matrix, input_features_daily, input_features_individual, input_mask_daily, input_mask_individual], outputs=output)
    model.compile(optimizer=Adam(learning_rate=2e-4), loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
    return model
    
# Function to create an efficient TF dataset
def prepare_tf_dataset(X_matrix, X_features1, X_features2, X_mask1, X_mask2, y, batch_size=16, shuffle=True):
    dataset = tf.data.Dataset.from_tensor_slices(((X_matrix, X_features1, X_features2, X_mask1, X_mask2), y))
    
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(y), reshuffle_each_iteration=True)
    
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset
def prepare_tf_dataset_mask(X_matrix, X_features1, X_features2,X_mask1, X_mask2, y, batch_size=16, shuffle=True):
    def data_generator():
        for i in range(len(y)):
            yield (X_matrix[i], X_features1[i], X_features2[i], X_mask1[i], X_mask2[i]), y[i]
    
    dataset = tf.data.Dataset.from_generator(
        data_generator,
        output_signature=(
            (
                tf.TensorSpec(shape=(288, 288, 3), dtype=tf.float64),  # Matrix input
                tf.TensorSpec(shape=(dailyshape,), dtype=tf.float16),         # Feature vector 1
                tf.TensorSpec(shape=(individualshape,), dtype=tf.float64),          # Feature vector 2
                tf.TensorSpec(shape=(dailyshape,), dtype=tf.float16),         # Mask vector 1
                tf.TensorSpec(shape=(individualshape,), dtype=tf.float16)          # Mask vector 2            
            ),
            tf.TensorSpec(shape=(), dtype=tf.float16)  # Target variable
        )
    )
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(y), reshuffle_each_iteration=True)
    
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset
 
def get_train_val_test_indices(participant_ids, train_val_idx, test_idx):
    model_participants = np.unique(participant_ids)
    model_participants = shuffle(model_participants, random_state=42)
    # 75% of the data as train set
    train_val_participants = model_participants[np.isin(model_participants, participant_ids[train_val_idx])]
    test_participants = model_participants[np.isin(model_participants, participant_ids[test_idx])]
    train_size = int(len(train_val_participants) * 8 / 9)
    train_participants = train_val_participants[:train_size]
    val_participants = train_val_participants[train_size:]
    print(f"{len(train_participants)}, {len(val_participants)}, {len(test_participants)}, participants in Train, Validation, and Test sets" )
    
    train_idx = np.where(np.isin(participant_ids, train_participants))[0]
    val_idx = np.where(np.isin(participant_ids, val_participants))[0]
    return train_idx, val_idx

def train_and_evaluate_resampled_model_mask(fold, train_idx, val_idx, X_matrix,X_daily_features,X_individual_features, y_labels, num_epochs=40, batch_s=16, num_patience=20, monitored='val_loss'):
    model = create_model_3d()
    
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor=monitored, patience=num_patience, restore_best_weights=True)
    learning_rate_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor=monitored, factor=0.5, patience=4, min_lr=1e-7)
    checkpoint = ModelCheckpoint(filepath=os.path.join(folder_name, 'best_model_fold_{}.keras'.format(fold)), monitor='val_accuracy', save_best_only=True, mode='max')

    X_train_resampled,X_daily_train_resampled,X_individual_train_resampled, y_label_train_resampled = apply_smote_resampling(
        X_matrix[train_idx],X_daily_features[train_idx],X_individual_features[train_idx],
        y_labels[train_idx], matrix_shape0=matrix_shape0
    )
    X_val_resampled,X_daily_val_resampled,X_individual_val_resampled, y_label_val_resampled = apply_smote_resampling(
        X_matrix[val_idx],X_daily_features[val_idx],X_individual_features[val_idx],
        y_labels[val_idx], matrix_shape0=matrix_shape0
    )
    train_dataset = prepare_tf_dataset(X_train_resampled,X_daily_train_resampled,X_individual_train_resampled, y_label_train_resampled, batch_size=batch_s)
    val_dataset = prepare_tf_dataset(X_val_resampled,X_daily_val_resampled,X_individual_val_resampled, y_label_val_resampled, batch_size=batch_s, shuffle=False)
    del X_train_resampled,X_daily_train_resampled,X_individual_train_resampled, y_label_train_resampled
    del X_val_resampled,X_daily_val_resampled,X_individual_val_resampled, y_label_val_resampled
    # gc.collect()
    history = model.fit(train_dataset, epochs=num_epochs, verbose=1, validation_data=val_dataset, callbacks=[early_stopping, learning_rate_scheduler, checkpoint])
    del train_dataset, val_dataset, early_stopping, learning_rate_scheduler, checkpoint
    gc.collect()
    return model, history
    
def train_and_evaluate_model_mask(fold, train_idx,val_idx, X_matrix, X_daily_features,X_individual_features, mask_daily, mask_individual, y_labels, num_epochs=40, batch_s=16, num_patience=20, monitored='val_loss'):
    model = create_model_mask()

    early_stopping = keras.callbacks.EarlyStopping(monitor=monitored, patience=num_patience, restore_best_weights=True)
    learning_rate_scheduler = keras.callbacks.ReduceLROnPlateau(monitor=monitored, factor=0.5, patience=4, min_lr=1e-7)
    checkpoint = ModelCheckpoint(filepath=os.path.join(folder_name, 'best_model_fold_{}.keras'.format(fold)), monitor='val_accuracy', save_best_only=True, mode='max')
    train_dataset = prepare_tf_dataset(X_matrix[train_idx], X_daily_features[train_idx], X_individual_features[train_idx],mask_daily[train_idx], mask_individual[train_idx], y_labels[train_idx], batch_size=batch_s)
    val_dataset = prepare_tf_dataset(X_matrix[val_idx], X_daily_features[val_idx], X_individual_features[val_idx],mask_daily[val_idx], mask_individual[val_idx], y_labels[val_idx], batch_size=batch_s, shuffle=False)
    
    class_weights = compute_class_weight('balanced', classes=np.unique(y_labels[train_idx]), y=y_labels[train_idx].ravel())
    class_weight_dict = dict(enumerate(class_weights))
    print("Class weights: ", class_weight_dict)
    history = model.fit(train_dataset, epochs=num_epochs, verbose=1, validation_data=val_dataset, callbacks=[early_stopping, learning_rate_scheduler,checkpoint],class_weight=class_weight_dict)
    del train_dataset, val_dataset
    gc.collect()
    return model, history

def evaluate_performance_mask(model, test_idx, X_matrices, X_daily_features, X_individual_features,mask_daily, mask_individual, y_labels, threshold=0.3):
    y_pred_test = model.predict([X_matrices[test_idx], X_daily_features[test_idx], X_individual_features[test_idx],mask_daily[test_idx], mask_individual[test_idx]])
    y_pred_test_binary = (y_pred_test >= threshold).astype(int)
    
    return {
        "accuracy_scores": accuracy_score(y_labels[test_idx], y_pred_test_binary),
        "recall_scores": recall_score(y_labels[test_idx], y_pred_test_binary),
        "precision_scores": precision_score(y_labels[test_idx], y_pred_test_binary),
        "f1_scores": f1_score(y_labels[test_idx], y_pred_test_binary),
        "specificity_scores": recall_score(y_labels[test_idx], y_pred_test_binary, pos_label=0),
        "roc_auc_scores": roc_auc_score(y_labels[test_idx], y_pred_test),
        "conf_matrix": confusion_matrix(y_labels[test_idx], y_pred_test_binary)}

def get_target_results_mask(models, num_splits, X_matrices, X_daily_features, X_individual_features,mask_daily, mask_individual,participant_ids, y_labels):
    # Initialize arrays to store predictions from each fold
    y_pred_target_agg = np.zeros((len(y_labels),)) 
    # Aggregate predictions from each fold model
    for model in models:
        y_pred_target_fold = model.predict([X_matrices, X_daily_features, X_individual_features,mask_daily, mask_individual])
        y_pred_target_agg += y_pred_target_fold.flatten()  # Accumulate predictions
        y_pred_target_avg = np.mean(y_pred_target_fold, axis=0)
    # Average the predictions from all folds
    y_pred_target_agg /= num_splits
    
    y_pred_target_binary_agg = (y_pred_target_agg >= 0.42).astype(int)
    conf_matrix = confusion_matrix(y_labels, y_pred_target_binary_agg)
    
    # Compute recall per participant
    df_results = pd.DataFrame({
        "participant_id": participant_ids.astype(int),
        "y_true": y_labels.flatten(),
        "y_pred_binary": y_pred_target_binary_agg
    })

    recall_per_participant = df_results.groupby("participant_id").apply(lambda g: recall_score(g["y_true"], g["y_pred_binary"]) if sum(g["y_true"]) > 0 else np.nan)

    return {
        "accuracy_scores": accuracy_score(y_labels, y_pred_target_binary_agg),
        "recall_scores": recall_score(y_labels, y_pred_target_binary_agg),
        "recall_scores_per_participant": recall_per_participant,
        "precision_scores": precision_score(y_labels, y_pred_target_binary_agg),
        "f1_scores": f1_score(y_labels, y_pred_target_binary_agg),
        "specificity_scores": recall_score(y_labels, y_pred_target_binary_agg, pos_label=0),
        "roc_auc_scores": roc_auc_score(y_labels, y_pred_target_agg),
        "conf_matrix": confusion_matrix(y_labels, y_pred_target_binary_agg)
    }

def cross_validation_holdout_analysis(label_name, num_splits=7, num_epochs=30, batch_s=32, num_patience=10, monitored='val_loss',threshold=0.3):
    configure_gpu()
    results = initialize_results()
    group_kfold = GroupKFold(n_splits=num_splits)
    file_path = '/home/__/data_generated/Adult/dict_3d_cgm_mex_morl_smooth_updated.dill'
    X_matrices, X_daily_features, X_individual_features, labels, participant_ids = prepare_datasets(file_path)
    y_labels = labels[label_name]
    model_participants = np.unique(participant_ids)
    model_participants = shuffle(model_participants, random_state=42)

    with tf.distribute.MirroredStrategy().scope():
        for fold, (train_val_idx, test_idx) in enumerate(group_kfold.split(X_matrices, y_labels, groups=participant_ids)):
            train_idx, val_idx = get_train_val_test_indices(participant_ids, train_val_idx, test_idx)
            print(f"Processing fold {fold + 1}...")
            X_daily_imputed = np.nan_to_num(X_daily_features, nan=0.0)
            X_individual_imputed = np.nan_to_num(X_individual_features, nan=0.0)
            
            # Create masks for missing values
            mask_daily = np.isfinite(X_daily_features).astype(np.float16)
            mask_individual = np.isfinite(X_individual_features).astype(np.float16)

            model, model_history = train_and_evaluate_model_mask(fold, train_idx,  val_idx, X_matrices, X_daily_imputed, X_individual_imputed,mask_daily, mask_individual, y_labels, 
                                                                 num_epochs, batch_s, num_patience, monitored)
    
            fold_results = evaluate_performance_mask(model, test_idx, X_matrices, X_daily_imputed, X_individual_imputed,mask_daily, mask_individual, y_labels, threshold)
            
            for key in results.keys():
                if key in fold_results.keys():
                    results[key].append(fold_results[key])
            results["fold_model"].append(model)
            results["fold_train_acc"].append(model_history.history['accuracy'])
            results["fold_train_auc"].append(model_history.history['AUC'])
            results["fold_train_loss"].append(model_history.history['loss'])
            results["fold_val_acc"].append(model_history.history['val_accuracy'])
            results["fold_val_auc"].append(model_history.history['val_AUC'])
            results["fold_val_loss"].append(model_history.history['val_loss'])
            
            print(f"\nFold {fold + 1} - {fold_results}")
            print("\n", fold_results["roc_auc_scores"])
            # Free GPU memory
            del model, model_history,fold_results
            gc.collect()
    del X_matrices, X_daily_features, X_individual_features, labels, participant_ids
    gc.collect()
    # Calculate and print average and std across folds
    print(f'\nAverage Test Accuracy: {np.mean(results["accuracy_scores"]):.4f} (+- {np.std(results["accuracy_scores"]):.4f})')
    print(f'Average Test Recall: {np.mean(results["recall_scores"]):.4f} (+- {np.std(results["recall_scores"]):.4f})')
    print(f'Average Test Specificity: {np.mean(results["specificity_scores"]):.4f} (+- {np.std(results["specificity_scores"]):.4f})')
    print(f'Average Test AUC: {np.mean(results["roc_auc_scores"]):.4f} (+- {np.std(results["roc_auc_scores"]):.4f})')

    print(f"Aggregated Models on Pediatric set ... \n")
    file_path = '/home/__/data_generated/Pediatric/FullFeatures/full_pediatric_cgm_mex_morl_smooth.dill'
    target_matrices, target_daily_features, target_individual_features, labels,target_participant_ids = prepare_datasets(file_path)
    target_labels = labels[label_name]
    target_daily_imputed = np.nan_to_num(target_daily_features, nan=0.0)
    target_individual_imputed = np.nan_to_num(target_individual_features, nan=0.0)
    
    # Create masks for missing values
    target_mask_daily = np.isfinite(target_daily_features).astype(np.float16)
    target_mask_individual = np.isfinite(target_individual_features).astype(np.float16)
    target_results = get_target_results_mask(results["fold_model"],num_splits, target_matrices, target_daily_imputed, target_individual_imputed,target_mask_daily,target_mask_individual,target_participant_ids, target_labels)

    print(f'Target Accuracy: {target_results["accuracy_scores"]:.4f}')
    print(f'Target Recall: {target_results["recall_scores"]:.4f}')
    print(f'Target Specificity: {target_results["specificity_scores"]:.4f}')
    print(f'Target ROC AUC: {target_results["roc_auc_scores"]:.4f} \n')
    
    pediatric_hbA1c_values = target_individual_features[:, 0] 
    # y_true = target_labels
    # y_pred_binary = (target_results["recall_scores"] >= 0.25).astype(int)
    # df_results = pd.DataFrame({
    #     "participant_id": target_participant_ids.astype(int),
    #     "y_true": y_true,
    #     "y_pred_binary": y_pred_binary})    
    # df_results = df_results[df_results.groupby("participant_id")["y_true"].transform("sum") > 0]
    df = pd.DataFrame({'participant_id': target_participant_ids.astype(int), 'HbA1c': pediatric_hbA1c_values})
    df = df.groupby('participant_id', as_index=False).mean()
    
    df_recall = target_results["recall_scores_per_participant"].reset_index()
    df_recall.columns = ["participant_id", "avg_recall"]
    df_recall.dropna(inplace=True)
    # df_recall = df_results.groupby("participant_id").apply(lambda x: recall_score(x["y_true"], x["y_pred_binary"])).reset_index()
    # df_recall.columns = ["participant_id", "avg_recall"]
    
    # Merge with HbA1c values
    df_plot = pd.merge(df_recall, df, on="participant_id")
    
    # Plot
    plt.figure(figsize=(8, 6))
    plt.scatter(df_plot["HbA1c"], df_plot["avg_recall"], alpha=0.7, edgecolors="black", color="blue")
    plt.xlabel("HbA1c")
    plt.ylabel("Average Recall Score")
    plt.title('Hypoglycemia Prediction vs HbA1c')
    plt.grid(True)
    plt.show()
    plot_training_history(results["fold_val_loss"], results["fold_val_auc"], results["fold_val_acc"], folder_name)
    return results, target_results

# %%
# learning_rate=2e-4
# Resampled
# checkpoint
# monitor='val_loss'
# 10 split
# batch 32

# %matplotlib inline

matrix_shape0 = 288
dailyshape = 327
individualshape = 324
folder_name = "/home/__/results/holdoutResultsFull/NightMorning1"
configure_gpu()
# Perform K-Fold Cross-Validation with Transfer Learning
source_results, target_results = cross_validation_holdout_analysis(label_name="hypo_night_morning",num_splits=10, num_epochs=60,batch_s=32, num_patience=15, monitored='val_loss',threshold=0.5)

gc.collect()
# Save results for comparison
saved_results = "/home/__/results/holdoutResultsFull/NightMorning1/source_results.npy"
np.save(saved_results, source_results)
# Save results for comparison
saved_results = "/home/__/results/holdoutResultsFull/NightMorning1/target_results.npy"
np.save(saved_results, target_results)
# Out:
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 1...
# Class weights:  {0: 0.6775597404652635, 1: 1.9079768270944741}
# Epoch 1/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 26s 58ms/step - AUC: 0.5060 - accuracy: 0.5213 - loss: 3.4864 - val_AUC: 0.5081 - val_accuracy: 0.5038 - val_loss: 2.8951 - learning_rate: 2.0000e-04
# Epoch 2/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - AUC: 0.5072 - accuracy: 0.5064 - loss: 2.8966 - val_AUC: 0.5093 - val_accuracy: 0.6147 - val_loss: 2.6428 - learning_rate: 2.0000e-04
# Epoch 3/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.5108 - accuracy: 0.5261 - loss: 2.6258 - val_AUC: 0.5077 - val_accuracy: 0.4680 - val_loss: 2.4221 - learning_rate: 2.0000e-04
# Epoch 4/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - AUC: 0.5490 - accuracy: 0.5177 - loss: 2.3658 - val_AUC: 0.6665 - val_accuracy: 0.6278 - val_loss: 2.1606 - learning_rate: 2.0000e-04
# Epoch 5/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - AUC: 0.6440 - accuracy: 0.5908 - loss: 2.1071 - val_AUC: 0.7135 - val_accuracy: 0.6729 - val_loss: 1.8987 - learning_rate: 2.0000e-04
# Epoch 6/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.7177 - accuracy: 0.6570 - loss: 1.8616 - val_AUC: 0.7147 - val_accuracy: 0.6504 - val_loss: 1.7024 - learning_rate: 2.0000e-04
# Epoch 7/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - AUC: 0.7402 - accuracy: 0.6859 - loss: 1.6733 - val_AUC: 0.7554 - val_accuracy: 0.6823 - val_loss: 1.5234 - learning_rate: 2.0000e-04
# Epoch 8/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - AUC: 0.7687 - accuracy: 0.6977 - loss: 1.4866 - val_AUC: 0.7880 - val_accuracy: 0.7556 - val_loss: 1.3475 - learning_rate: 2.0000e-04
# Epoch 9/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.7987 - accuracy: 0.7314 - loss: 1.3327 - val_AUC: 0.7956 - val_accuracy: 0.7387 - val_loss: 1.2161 - learning_rate: 2.0000e-04
# Epoch 10/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.8197 - accuracy: 0.7528 - loss: 1.1942 - val_AUC: 0.8023 - val_accuracy: 0.7425 - val_loss: 1.1494 - learning_rate: 2.0000e-04
# Epoch 11/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.8335 - accuracy: 0.7557 - loss: 1.0859 - val_AUC: 0.8178 - val_accuracy: 0.7256 - val_loss: 1.0734 - learning_rate: 2.0000e-04
# Epoch 12/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.8451 - accuracy: 0.7771 - loss: 0.9924 - val_AUC: 0.8111 - val_accuracy: 0.7180 - val_loss: 0.9783 - learning_rate: 2.0000e-04
# Epoch 13/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.8549 - accuracy: 0.7850 - loss: 0.9272 - val_AUC: 0.8139 - val_accuracy: 0.7650 - val_loss: 0.9101 - learning_rate: 2.0000e-04
# Epoch 14/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.8691 - accuracy: 0.7952 - loss: 0.8448 - val_AUC: 0.8220 - val_accuracy: 0.7763 - val_loss: 0.8512 - learning_rate: 2.0000e-04
# Epoch 15/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.8865 - accuracy: 0.8080 - loss: 0.7822 - val_AUC: 0.8149 - val_accuracy: 0.7481 - val_loss: 0.8304 - learning_rate: 2.0000e-04
# Epoch 16/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.8987 - accuracy: 0.8192 - loss: 0.7291 - val_AUC: 0.7913 - val_accuracy: 0.7086 - val_loss: 0.8439 - learning_rate: 2.0000e-04
# Epoch 17/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9021 - accuracy: 0.8225 - loss: 0.7024 - val_AUC: 0.8083 - val_accuracy: 0.7293 - val_loss: 0.7960 - learning_rate: 2.0000e-04
# Epoch 18/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9221 - accuracy: 0.8522 - loss: 0.6389 - val_AUC: 0.8148 - val_accuracy: 0.7575 - val_loss: 0.7558 - learning_rate: 2.0000e-04
# Epoch 19/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9324 - accuracy: 0.8585 - loss: 0.6016 - val_AUC: 0.8110 - val_accuracy: 0.7293 - val_loss: 0.8103 - learning_rate: 2.0000e-04
# Epoch 20/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9471 - accuracy: 0.8765 - loss: 0.5549 - val_AUC: 0.8058 - val_accuracy: 0.7688 - val_loss: 0.7556 - learning_rate: 2.0000e-04
# Epoch 21/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9605 - accuracy: 0.8927 - loss: 0.5067 - val_AUC: 0.7980 - val_accuracy: 0.7575 - val_loss: 0.8133 - learning_rate: 2.0000e-04
# Epoch 22/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.9696 - accuracy: 0.9104 - loss: 0.4708 - val_AUC: 0.8078 - val_accuracy: 0.7989 - val_loss: 0.8228 - learning_rate: 2.0000e-04
# Epoch 23/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9798 - accuracy: 0.9294 - loss: 0.4246 - val_AUC: 0.8043 - val_accuracy: 0.7801 - val_loss: 0.8354 - learning_rate: 2.0000e-04
# Epoch 24/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9817 - accuracy: 0.9301 - loss: 0.4130 - val_AUC: 0.8167 - val_accuracy: 0.7857 - val_loss: 0.8455 - learning_rate: 2.0000e-04
# Epoch 25/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9921 - accuracy: 0.9607 - loss: 0.3423 - val_AUC: 0.7987 - val_accuracy: 0.7989 - val_loss: 1.0419 - learning_rate: 1.0000e-04
# Epoch 26/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9979 - accuracy: 0.9809 - loss: 0.2755 - val_AUC: 0.7689 - val_accuracy: 0.7707 - val_loss: 1.3713 - learning_rate: 1.0000e-04
# Epoch 27/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9977 - accuracy: 0.9819 - loss: 0.2619 - val_AUC: 0.7812 - val_accuracy: 0.7838 - val_loss: 1.3153 - learning_rate: 1.0000e-04
# Epoch 28/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9986 - accuracy: 0.9882 - loss: 0.2429 - val_AUC: 0.7914 - val_accuracy: 0.7801 - val_loss: 1.2668 - learning_rate: 1.0000e-04
# Epoch 29/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 50ms/step - AUC: 0.9996 - accuracy: 0.9891 - loss: 0.2230 - val_AUC: 0.7676 - val_accuracy: 0.8008 - val_loss: 1.5189 - learning_rate: 5.0000e-05
# Epoch 30/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9998 - accuracy: 0.9975 - loss: 0.2005 - val_AUC: 0.7564 - val_accuracy: 0.7820 - val_loss: 1.6606 - learning_rate: 5.0000e-05
# Epoch 31/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9999 - accuracy: 0.9968 - loss: 0.1947 - val_AUC: 0.7523 - val_accuracy: 0.7876 - val_loss: 1.6128 - learning_rate: 5.0000e-05
# Epoch 32/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9997 - accuracy: 0.9967 - loss: 0.1911 - val_AUC: 0.7615 - val_accuracy: 0.7989 - val_loss: 1.6826 - learning_rate: 5.0000e-05
# Epoch 33/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 1.0000 - accuracy: 0.9977 - loss: 0.1818 - val_AUC: 0.7665 - val_accuracy: 0.7895 - val_loss: 1.7025 - learning_rate: 2.5000e-05
# Epoch 34/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 1.0000 - accuracy: 0.9994 - loss: 0.1748 - val_AUC: 0.7458 - val_accuracy: 0.7838 - val_loss: 1.9319 - learning_rate: 2.5000e-05
# Epoch 35/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9999 - accuracy: 0.9993 - loss: 0.1717 - val_AUC: 0.7489 - val_accuracy: 0.7989 - val_loss: 1.9338 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Fold 1 - {'accuracy_scores': 0.7427325581395349, 'recall_scores': 0.6973293768545994, 'precision_scores': 0.48254620123203285, 'f1_scores': 0.5703883495145631, 'specificity_scores': 0.7574590952839269, 'roc_auc_scores': 0.8075643379990461, 'conf_matrix': array([[787, 252],
#        [102, 235]])}
#
#  0.8075643379990461
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 2...
# Class weights:  {0: 0.6743601821322028, 1: 1.9338135974786133}
# Epoch 1/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - AUC: 0.4997 - accuracy: 0.5160 - loss: 3.4979 - val_AUC: 0.5618 - val_accuracy: 0.4470 - val_loss: 2.9126 - learning_rate: 2.0000e-04
# Epoch 2/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 0.4951 - accuracy: 0.4984 - loss: 2.9163 - val_AUC: 0.5067 - val_accuracy: 0.5549 - val_loss: 2.6688 - learning_rate: 2.0000e-04
# Epoch 3/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.5029 - accuracy: 0.4902 - loss: 2.6622 - val_AUC: 0.4635 - val_accuracy: 0.6435 - val_loss: 2.4276 - learning_rate: 2.0000e-04
# Epoch 4/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.5281 - accuracy: 0.5278 - loss: 2.4082 - val_AUC: 0.6399 - val_accuracy: 0.5607 - val_loss: 2.2070 - learning_rate: 2.0000e-04
# Epoch 5/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.5958 - accuracy: 0.5678 - loss: 2.1555 - val_AUC: 0.6899 - val_accuracy: 0.6358 - val_loss: 1.9687 - learning_rate: 2.0000e-04
# Epoch 6/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - AUC: 0.7120 - accuracy: 0.6478 - loss: 1.8936 - val_AUC: 0.6999 - val_accuracy: 0.6628 - val_loss: 1.7635 - learning_rate: 2.0000e-04
# Epoch 7/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.7453 - accuracy: 0.6815 - loss: 1.7014 - val_AUC: 0.7430 - val_accuracy: 0.6859 - val_loss: 1.5850 - learning_rate: 2.0000e-04
# Epoch 8/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - AUC: 0.7870 - accuracy: 0.7197 - loss: 1.5086 - val_AUC: 0.7610 - val_accuracy: 0.7052 - val_loss: 1.4381 - learning_rate: 2.0000e-04
# Epoch 9/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - AUC: 0.8058 - accuracy: 0.7316 - loss: 1.3521 - val_AUC: 0.7497 - val_accuracy: 0.6898 - val_loss: 1.3254 - learning_rate: 2.0000e-04
# Epoch 10/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8114 - accuracy: 0.7424 - loss: 1.2370 - val_AUC: 0.7451 - val_accuracy: 0.6301 - val_loss: 1.2645 - learning_rate: 2.0000e-04
# Epoch 11/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - AUC: 0.8324 - accuracy: 0.7571 - loss: 1.1286 - val_AUC: 0.7752 - val_accuracy: 0.7033 - val_loss: 1.1369 - learning_rate: 2.0000e-04
# Epoch 12/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8594 - accuracy: 0.7764 - loss: 1.0077 - val_AUC: 0.7832 - val_accuracy: 0.7071 - val_loss: 1.0619 - learning_rate: 2.0000e-04
# Epoch 13/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8680 - accuracy: 0.7925 - loss: 0.9319 - val_AUC: 0.7743 - val_accuracy: 0.7303 - val_loss: 0.9809 - learning_rate: 2.0000e-04
# Epoch 14/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8682 - accuracy: 0.8000 - loss: 0.8822 - val_AUC: 0.7801 - val_accuracy: 0.7283 - val_loss: 0.9381 - learning_rate: 2.0000e-04
# Epoch 15/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8863 - accuracy: 0.8062 - loss: 0.8134 - val_AUC: 0.7688 - val_accuracy: 0.7514 - val_loss: 0.8770 - learning_rate: 2.0000e-04
# Epoch 16/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.9021 - accuracy: 0.8214 - loss: 0.7520 - val_AUC: 0.7842 - val_accuracy: 0.7283 - val_loss: 0.8769 - learning_rate: 2.0000e-04
# Epoch 17/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9134 - accuracy: 0.8473 - loss: 0.6989 - val_AUC: 0.7656 - val_accuracy: 0.7110 - val_loss: 0.8860 - learning_rate: 2.0000e-04
# Epoch 18/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9173 - accuracy: 0.8369 - loss: 0.6777 - val_AUC: 0.7748 - val_accuracy: 0.7052 - val_loss: 0.8867 - learning_rate: 2.0000e-04
# Epoch 19/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9316 - accuracy: 0.8535 - loss: 0.6354 - val_AUC: 0.7601 - val_accuracy: 0.7187 - val_loss: 0.8576 - learning_rate: 2.0000e-04
# Epoch 20/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.9447 - accuracy: 0.8680 - loss: 0.5853 - val_AUC: 0.7679 - val_accuracy: 0.7052 - val_loss: 0.8610 - learning_rate: 2.0000e-04
# Epoch 21/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9494 - accuracy: 0.8763 - loss: 0.5562 - val_AUC: 0.7569 - val_accuracy: 0.7071 - val_loss: 0.9308 - learning_rate: 2.0000e-04
# Epoch 22/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - AUC: 0.9629 - accuracy: 0.8929 - loss: 0.5060 - val_AUC: 0.7869 - val_accuracy: 0.6956 - val_loss: 0.8806 - learning_rate: 2.0000e-04
# Epoch 23/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9653 - accuracy: 0.8891 - loss: 0.5014 - val_AUC: 0.7633 - val_accuracy: 0.7457 - val_loss: 1.0467 - learning_rate: 2.0000e-04
# Epoch 24/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9853 - accuracy: 0.9362 - loss: 0.4095 - val_AUC: 0.7515 - val_accuracy: 0.7013 - val_loss: 1.1374 - learning_rate: 1.0000e-04
# Epoch 25/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - AUC: 0.9943 - accuracy: 0.9616 - loss: 0.3366 - val_AUC: 0.7633 - val_accuracy: 0.7322 - val_loss: 1.3245 - learning_rate: 1.0000e-04
# Epoch 26/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9954 - accuracy: 0.9688 - loss: 0.3125 - val_AUC: 0.7618 - val_accuracy: 0.7245 - val_loss: 1.3382 - learning_rate: 1.0000e-04
# Epoch 27/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9983 - accuracy: 0.9829 - loss: 0.2752 - val_AUC: 0.7446 - val_accuracy: 0.7071 - val_loss: 1.5463 - learning_rate: 1.0000e-04
# Epoch 28/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9977 - accuracy: 0.9809 - loss: 0.2729 - val_AUC: 0.7514 - val_accuracy: 0.7264 - val_loss: 1.6992 - learning_rate: 5.0000e-05
# Epoch 29/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9997 - accuracy: 0.9928 - loss: 0.2339 - val_AUC: 0.7306 - val_accuracy: 0.7225 - val_loss: 1.8793 - learning_rate: 5.0000e-05
# Epoch 30/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9996 - accuracy: 0.9922 - loss: 0.2304 - val_AUC: 0.7321 - val_accuracy: 0.7360 - val_loss: 1.9057 - learning_rate: 5.0000e-05
# Epoch 31/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9998 - accuracy: 0.9933 - loss: 0.2172 - val_AUC: 0.7326 - val_accuracy: 0.7322 - val_loss: 1.8945 - learning_rate: 5.0000e-05
# Epoch 32/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9999 - accuracy: 0.9949 - loss: 0.2084 - val_AUC: 0.7295 - val_accuracy: 0.7283 - val_loss: 2.0266 - learning_rate: 2.5000e-05
# Epoch 33/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 1.0000 - accuracy: 0.9986 - loss: 0.1972 - val_AUC: 0.7215 - val_accuracy: 0.7360 - val_loss: 2.1268 - learning_rate: 2.5000e-05
# Epoch 34/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 1.0000 - accuracy: 0.9996 - loss: 0.1909 - val_AUC: 0.7191 - val_accuracy: 0.7380 - val_loss: 2.2308 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
#
# Fold 2 - {'accuracy_scores': 0.7083636363636364, 'recall_scores': 0.7909604519774012, 'precision_scores': 0.4612850082372323, 'f1_scores': 0.5827263267429761, 'specificity_scores': 0.6797257590597453, 'roc_auc_scores': 0.8110056054494045, 'conf_matrix': array([[694, 327],
#        [ 74, 280]])}
#
#  0.8110056054494045
# 381, 48, 62, participants in Train, Validation, and Test sets
# Processing fold 3...
# Class weights:  {0: 0.675, 1: 1.9285714285714286}
# Epoch 1/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - AUC: 0.4863 - accuracy: 0.5146 - loss: 3.4828 - val_AUC: 0.5022 - val_accuracy: 0.4050 - val_loss: 2.9304 - learning_rate: 2.0000e-04
# Epoch 2/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.5070 - accuracy: 0.5059 - loss: 2.9334 - val_AUC: 0.5535 - val_accuracy: 0.4357 - val_loss: 2.7027 - learning_rate: 2.0000e-04
# Epoch 3/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.5073 - accuracy: 0.4871 - loss: 2.6830 - val_AUC: 0.6115 - val_accuracy: 0.6161 - val_loss: 2.4567 - learning_rate: 2.0000e-04
# Epoch 4/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.5405 - accuracy: 0.5279 - loss: 2.4228 - val_AUC: 0.6893 - val_accuracy: 0.5739 - val_loss: 2.2314 - learning_rate: 2.0000e-04
# Epoch 5/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.6350 - accuracy: 0.5945 - loss: 2.1538 - val_AUC: 0.7302 - val_accuracy: 0.5835 - val_loss: 1.9987 - learning_rate: 2.0000e-04
# Epoch 6/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.7465 - accuracy: 0.6558 - loss: 1.8934 - val_AUC: 0.7561 - val_accuracy: 0.6660 - val_loss: 1.7439 - learning_rate: 2.0000e-04
# Epoch 7/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - AUC: 0.7800 - accuracy: 0.6987 - loss: 1.6685 - val_AUC: 0.7748 - val_accuracy: 0.6583 - val_loss: 1.5887 - learning_rate: 2.0000e-04
# Epoch 8/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.7968 - accuracy: 0.7232 - loss: 1.5027 - val_AUC: 0.7944 - val_accuracy: 0.7255 - val_loss: 1.3830 - learning_rate: 2.0000e-04
# Epoch 9/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.8217 - accuracy: 0.7511 - loss: 1.3223 - val_AUC: 0.7929 - val_accuracy: 0.6756 - val_loss: 1.3172 - learning_rate: 2.0000e-04
# Epoch 10/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.8304 - accuracy: 0.7675 - loss: 1.1983 - val_AUC: 0.8083 - val_accuracy: 0.6967 - val_loss: 1.2101 - learning_rate: 2.0000e-04
# Epoch 11/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.8564 - accuracy: 0.7794 - loss: 1.0705 - val_AUC: 0.8202 - val_accuracy: 0.7351 - val_loss: 1.0556 - learning_rate: 2.0000e-04
# Epoch 12/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.8589 - accuracy: 0.7949 - loss: 0.9847 - val_AUC: 0.8163 - val_accuracy: 0.7716 - val_loss: 0.9779 - learning_rate: 2.0000e-04
# Epoch 13/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.8765 - accuracy: 0.8148 - loss: 0.8966 - val_AUC: 0.8204 - val_accuracy: 0.7774 - val_loss: 0.9278 - learning_rate: 2.0000e-04
# Epoch 14/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.8819 - accuracy: 0.8135 - loss: 0.8386 - val_AUC: 0.8259 - val_accuracy: 0.7697 - val_loss: 0.8636 - learning_rate: 2.0000e-04
# Epoch 15/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - AUC: 0.8947 - accuracy: 0.8198 - loss: 0.7922 - val_AUC: 0.8102 - val_accuracy: 0.7332 - val_loss: 0.8894 - learning_rate: 2.0000e-04
# Epoch 16/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9057 - accuracy: 0.8339 - loss: 0.7353 - val_AUC: 0.7937 - val_accuracy: 0.7159 - val_loss: 0.8887 - learning_rate: 2.0000e-04
# Epoch 17/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9095 - accuracy: 0.8400 - loss: 0.7113 - val_AUC: 0.8256 - val_accuracy: 0.7524 - val_loss: 0.8280 - learning_rate: 2.0000e-04
# Epoch 18/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9318 - accuracy: 0.8570 - loss: 0.6504 - val_AUC: 0.8033 - val_accuracy: 0.7524 - val_loss: 0.8432 - learning_rate: 2.0000e-04
# Epoch 19/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9463 - accuracy: 0.8755 - loss: 0.6017 - val_AUC: 0.8062 - val_accuracy: 0.7505 - val_loss: 0.8359 - learning_rate: 2.0000e-04
# Epoch 20/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9573 - accuracy: 0.8861 - loss: 0.5616 - val_AUC: 0.7916 - val_accuracy: 0.7179 - val_loss: 0.9290 - learning_rate: 2.0000e-04
# Epoch 21/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - AUC: 0.9682 - accuracy: 0.9071 - loss: 0.5264 - val_AUC: 0.7753 - val_accuracy: 0.7236 - val_loss: 0.9441 - learning_rate: 2.0000e-04
# Epoch 22/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9878 - accuracy: 0.9459 - loss: 0.4342 - val_AUC: 0.8019 - val_accuracy: 0.7409 - val_loss: 1.0636 - learning_rate: 1.0000e-04
# Epoch 23/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9955 - accuracy: 0.9718 - loss: 0.3564 - val_AUC: 0.7975 - val_accuracy: 0.7505 - val_loss: 1.1558 - learning_rate: 1.0000e-04
# Epoch 24/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9979 - accuracy: 0.9816 - loss: 0.3189 - val_AUC: 0.7774 - val_accuracy: 0.7582 - val_loss: 1.2490 - learning_rate: 1.0000e-04
# Epoch 25/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - AUC: 0.9984 - accuracy: 0.9814 - loss: 0.3002 - val_AUC: 0.7651 - val_accuracy: 0.7505 - val_loss: 1.4451 - learning_rate: 1.0000e-04
# Epoch 26/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9991 - accuracy: 0.9883 - loss: 0.2806 - val_AUC: 0.7759 - val_accuracy: 0.7735 - val_loss: 1.4320 - learning_rate: 5.0000e-05
# Epoch 27/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9998 - accuracy: 0.9937 - loss: 0.2566 - val_AUC: 0.7505 - val_accuracy: 0.7639 - val_loss: 1.6341 - learning_rate: 5.0000e-05
# Epoch 28/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9997 - accuracy: 0.9956 - loss: 0.2432 - val_AUC: 0.7715 - val_accuracy: 0.7658 - val_loss: 1.6460 - learning_rate: 5.0000e-05
# Epoch 29/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9999 - accuracy: 0.9967 - loss: 0.2324 - val_AUC: 0.7545 - val_accuracy: 0.7754 - val_loss: 1.7110 - learning_rate: 5.0000e-05
# Epoch 30/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - AUC: 1.0000 - accuracy: 0.9991 - loss: 0.2237 - val_AUC: 0.7551 - val_accuracy: 0.7658 - val_loss: 1.7742 - learning_rate: 2.5000e-05
# Epoch 31/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - AUC: 1.0000 - accuracy: 0.9984 - loss: 0.2158 - val_AUC: 0.7502 - val_accuracy: 0.7697 - val_loss: 1.8635 - learning_rate: 2.5000e-05
# Epoch 32/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 1.0000 - accuracy: 0.9985 - loss: 0.2135 - val_AUC: 0.7500 - val_accuracy: 0.7774 - val_loss: 1.8579 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
#
# Fold 3 - {'accuracy_scores': 0.6996363636363636, 'recall_scores': 0.6940509915014165, 'precision_scores': 0.44545454545454544, 'f1_scores': 0.5426356589147286, 'specificity_scores': 0.7015655577299413, 'roc_auc_scores': 0.7741832656070694, 'conf_matrix': array([[717, 305],
#        [108, 245]])}
#
#  0.7741832656070694
# 381, 48, 62, participants in Train, Validation, and Test sets
# Processing fold 4...
# Class weights:  {0: 0.679458775122646, 1: 1.8930776014109347}
# Epoch 1/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - AUC: 0.4860 - accuracy: 0.5040 - loss: 3.5238 - val_AUC: 0.5192 - val_accuracy: 0.6084 - val_loss: 2.8955 - learning_rate: 2.0000e-04
# Epoch 2/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.5294 - accuracy: 0.5212 - loss: 2.9001 - val_AUC: 0.5061 - val_accuracy: 0.6507 - val_loss: 2.6541 - learning_rate: 2.0000e-04
# Epoch 3/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - AUC: 0.5221 - accuracy: 0.5227 - loss: 2.6346 - val_AUC: 0.6013 - val_accuracy: 0.5125 - val_loss: 2.4325 - learning_rate: 2.0000e-04
# Epoch 4/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.5652 - accuracy: 0.5368 - loss: 2.3885 - val_AUC: 0.7059 - val_accuracy: 0.6545 - val_loss: 2.1671 - learning_rate: 2.0000e-04
# Epoch 5/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.6592 - accuracy: 0.5874 - loss: 2.1313 - val_AUC: 0.6883 - val_accuracy: 0.6987 - val_loss: 1.9150 - learning_rate: 2.0000e-04
# Epoch 6/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.7193 - accuracy: 0.6513 - loss: 1.8996 - val_AUC: 0.7377 - val_accuracy: 0.7179 - val_loss: 1.7207 - learning_rate: 2.0000e-04
# Epoch 7/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - AUC: 0.7660 - accuracy: 0.7024 - loss: 1.6909 - val_AUC: 0.7633 - val_accuracy: 0.6315 - val_loss: 1.6137 - learning_rate: 2.0000e-04
# Epoch 8/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.7942 - accuracy: 0.7071 - loss: 1.5031 - val_AUC: 0.7696 - val_accuracy: 0.6775 - val_loss: 1.4407 - learning_rate: 2.0000e-04
# Epoch 9/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.8023 - accuracy: 0.7269 - loss: 1.3651 - val_AUC: 0.7739 - val_accuracy: 0.7351 - val_loss: 1.2857 - learning_rate: 2.0000e-04
# Epoch 10/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.8312 - accuracy: 0.7624 - loss: 1.2104 - val_AUC: 0.7748 - val_accuracy: 0.6833 - val_loss: 1.2183 - learning_rate: 2.0000e-04
# Epoch 11/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.8504 - accuracy: 0.7781 - loss: 1.0882 - val_AUC: 0.7779 - val_accuracy: 0.7294 - val_loss: 1.0864 - learning_rate: 2.0000e-04
# Epoch 12/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.8631 - accuracy: 0.7800 - loss: 0.9969 - val_AUC: 0.7780 - val_accuracy: 0.5950 - val_loss: 1.1452 - learning_rate: 2.0000e-04
# Epoch 13/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.8671 - accuracy: 0.7858 - loss: 0.9347 - val_AUC: 0.8003 - val_accuracy: 0.7390 - val_loss: 0.9509 - learning_rate: 2.0000e-04
# Epoch 14/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.8736 - accuracy: 0.7957 - loss: 0.8727 - val_AUC: 0.7740 - val_accuracy: 0.7083 - val_loss: 0.9586 - learning_rate: 2.0000e-04
# Epoch 15/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.8840 - accuracy: 0.8090 - loss: 0.8273 - val_AUC: 0.7781 - val_accuracy: 0.7102 - val_loss: 0.9172 - learning_rate: 2.0000e-04
# Epoch 16/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9075 - accuracy: 0.8326 - loss: 0.7491 - val_AUC: 0.8046 - val_accuracy: 0.7121 - val_loss: 0.8843 - learning_rate: 2.0000e-04
# Epoch 17/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9063 - accuracy: 0.8229 - loss: 0.7358 - val_AUC: 0.7658 - val_accuracy: 0.7505 - val_loss: 0.8543 - learning_rate: 2.0000e-04
# Epoch 18/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9190 - accuracy: 0.8380 - loss: 0.6915 - val_AUC: 0.7976 - val_accuracy: 0.7562 - val_loss: 0.8123 - learning_rate: 2.0000e-04
# Epoch 19/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9363 - accuracy: 0.8609 - loss: 0.6282 - val_AUC: 0.7792 - val_accuracy: 0.6910 - val_loss: 0.8680 - learning_rate: 2.0000e-04
# Epoch 20/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.9482 - accuracy: 0.8708 - loss: 0.5865 - val_AUC: 0.7471 - val_accuracy: 0.7236 - val_loss: 0.9229 - learning_rate: 2.0000e-04
# Epoch 21/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.9602 - accuracy: 0.8929 - loss: 0.5416 - val_AUC: 0.7685 - val_accuracy: 0.6622 - val_loss: 0.9154 - learning_rate: 2.0000e-04
# Epoch 22/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9728 - accuracy: 0.9133 - loss: 0.4957 - val_AUC: 0.7753 - val_accuracy: 0.7063 - val_loss: 0.9618 - learning_rate: 2.0000e-04
# Epoch 23/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.9876 - accuracy: 0.9426 - loss: 0.4126 - val_AUC: 0.7544 - val_accuracy: 0.7140 - val_loss: 1.1752 - learning_rate: 1.0000e-04
# Epoch 24/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.9948 - accuracy: 0.9679 - loss: 0.3440 - val_AUC: 0.7454 - val_accuracy: 0.7006 - val_loss: 1.3439 - learning_rate: 1.0000e-04
# Epoch 25/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9951 - accuracy: 0.9634 - loss: 0.3314 - val_AUC: 0.7530 - val_accuracy: 0.7083 - val_loss: 1.3525 - learning_rate: 1.0000e-04
# Epoch 26/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9968 - accuracy: 0.9737 - loss: 0.3073 - val_AUC: 0.7452 - val_accuracy: 0.7486 - val_loss: 1.4135 - learning_rate: 1.0000e-04
# Epoch 27/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9982 - accuracy: 0.9848 - loss: 0.2758 - val_AUC: 0.7451 - val_accuracy: 0.7332 - val_loss: 1.5805 - learning_rate: 5.0000e-05
# Epoch 28/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9994 - accuracy: 0.9948 - loss: 0.2440 - val_AUC: 0.7231 - val_accuracy: 0.7140 - val_loss: 1.8124 - learning_rate: 5.0000e-05
# Epoch 29/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9999 - accuracy: 0.9982 - loss: 0.2286 - val_AUC: 0.7322 - val_accuracy: 0.7198 - val_loss: 1.9208 - learning_rate: 5.0000e-05
# Epoch 30/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9999 - accuracy: 0.9965 - loss: 0.2205 - val_AUC: 0.7282 - val_accuracy: 0.7236 - val_loss: 1.9078 - learning_rate: 5.0000e-05
# Epoch 31/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 1.0000 - accuracy: 0.9971 - loss: 0.2133 - val_AUC: 0.7293 - val_accuracy: 0.7370 - val_loss: 1.9510 - learning_rate: 2.5000e-05
# Epoch 32/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 1.0000 - accuracy: 0.9972 - loss: 0.2077 - val_AUC: 0.7157 - val_accuracy: 0.7255 - val_loss: 2.0653 - learning_rate: 2.5000e-05
# Epoch 33/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 1.0000 - accuracy: 0.9984 - loss: 0.2025 - val_AUC: 0.7342 - val_accuracy: 0.7255 - val_loss: 2.0539 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
#
# Fold 4 - {'accuracy_scores': 0.7723636363636364, 'recall_scores': 0.6444444444444445, 'precision_scores': 0.5024752475247525, 'f1_scores': 0.564673157162726, 'specificity_scores': 0.810377358490566, 'roc_auc_scores': 0.7938514525306978, 'conf_matrix': array([[859, 201],
#        [112, 203]])}
#
#  0.7938514525306978
# 381, 48, 62, participants in Train, Validation, and Test sets
# Processing fold 5...
# Class weights:  {0: 0.6752008823066016, 1: 1.92693345323741}
# Epoch 1/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - AUC: 0.5025 - accuracy: 0.5305 - loss: 3.5001 - val_AUC: 0.5394 - val_accuracy: 0.3535 - val_loss: 2.9540 - learning_rate: 2.0000e-04
# Epoch 2/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - AUC: 0.5070 - accuracy: 0.4916 - loss: 2.9431 - val_AUC: 0.5236 - val_accuracy: 0.4253 - val_loss: 2.7218 - learning_rate: 2.0000e-04
# Epoch 3/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 0.5327 - accuracy: 0.5250 - loss: 2.6875 - val_AUC: 0.6152 - val_accuracy: 0.5180 - val_loss: 2.4984 - learning_rate: 2.0000e-04
# Epoch 4/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - AUC: 0.5548 - accuracy: 0.5327 - loss: 2.4636 - val_AUC: 0.6935 - val_accuracy: 0.4953 - val_loss: 2.2883 - learning_rate: 2.0000e-04
# Epoch 5/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 0.6361 - accuracy: 0.5746 - loss: 2.2252 - val_AUC: 0.7159 - val_accuracy: 0.6805 - val_loss: 2.0344 - learning_rate: 2.0000e-04
# Epoch 6/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - AUC: 0.7340 - accuracy: 0.6596 - loss: 1.9741 - val_AUC: 0.7223 - val_accuracy: 0.7032 - val_loss: 1.8137 - learning_rate: 2.0000e-04
# Epoch 7/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.7682 - accuracy: 0.6970 - loss: 1.7691 - val_AUC: 0.7240 - val_accuracy: 0.6314 - val_loss: 1.6826 - learning_rate: 2.0000e-04
# Epoch 8/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.7784 - accuracy: 0.7175 - loss: 1.5912 - val_AUC: 0.7453 - val_accuracy: 0.6957 - val_loss: 1.4754 - learning_rate: 2.0000e-04
# Epoch 9/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 0.8117 - accuracy: 0.7365 - loss: 1.4164 - val_AUC: 0.7507 - val_accuracy: 0.6900 - val_loss: 1.3838 - learning_rate: 2.0000e-04
# Epoch 10/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - AUC: 0.8208 - accuracy: 0.7461 - loss: 1.2905 - val_AUC: 0.7752 - val_accuracy: 0.7335 - val_loss: 1.2291 - learning_rate: 2.0000e-04
# Epoch 11/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8405 - accuracy: 0.7717 - loss: 1.1566 - val_AUC: 0.7752 - val_accuracy: 0.7297 - val_loss: 1.1430 - learning_rate: 2.0000e-04
# Epoch 12/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8623 - accuracy: 0.7917 - loss: 1.0390 - val_AUC: 0.7926 - val_accuracy: 0.7127 - val_loss: 1.0798 - learning_rate: 2.0000e-04
# Epoch 13/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8530 - accuracy: 0.7856 - loss: 0.9817 - val_AUC: 0.7827 - val_accuracy: 0.7467 - val_loss: 0.9797 - learning_rate: 2.0000e-04
# Epoch 14/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8797 - accuracy: 0.8055 - loss: 0.8801 - val_AUC: 0.7994 - val_accuracy: 0.7070 - val_loss: 0.9834 - learning_rate: 2.0000e-04
# Epoch 15/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8873 - accuracy: 0.8086 - loss: 0.8236 - val_AUC: 0.7952 - val_accuracy: 0.7335 - val_loss: 0.9333 - learning_rate: 2.0000e-04
# Epoch 16/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9047 - accuracy: 0.8274 - loss: 0.7498 - val_AUC: 0.7830 - val_accuracy: 0.7524 - val_loss: 0.8440 - learning_rate: 2.0000e-04
# Epoch 17/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.9189 - accuracy: 0.8454 - loss: 0.7019 - val_AUC: 0.7896 - val_accuracy: 0.7051 - val_loss: 0.9046 - learning_rate: 2.0000e-04
# Epoch 18/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9276 - accuracy: 0.8538 - loss: 0.6614 - val_AUC: 0.7811 - val_accuracy: 0.7353 - val_loss: 0.8550 - learning_rate: 2.0000e-04
# Epoch 19/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9382 - accuracy: 0.8651 - loss: 0.6262 - val_AUC: 0.7907 - val_accuracy: 0.7183 - val_loss: 0.8395 - learning_rate: 2.0000e-04
# Epoch 20/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9511 - accuracy: 0.8804 - loss: 0.5782 - val_AUC: 0.7809 - val_accuracy: 0.7561 - val_loss: 0.8060 - learning_rate: 2.0000e-04
# Epoch 21/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - AUC: 0.9597 - accuracy: 0.8980 - loss: 0.5434 - val_AUC: 0.7728 - val_accuracy: 0.6900 - val_loss: 0.9988 - learning_rate: 2.0000e-04
# Epoch 22/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9688 - accuracy: 0.9005 - loss: 0.5137 - val_AUC: 0.7707 - val_accuracy: 0.6749 - val_loss: 1.0466 - learning_rate: 2.0000e-04
# Epoch 23/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.9784 - accuracy: 0.9223 - loss: 0.4652 - val_AUC: 0.7580 - val_accuracy: 0.7505 - val_loss: 0.9186 - learning_rate: 2.0000e-04
# Epoch 24/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9836 - accuracy: 0.9362 - loss: 0.4358 - val_AUC: 0.7486 - val_accuracy: 0.7297 - val_loss: 1.0454 - learning_rate: 2.0000e-04
# Epoch 25/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9944 - accuracy: 0.9621 - loss: 0.3566 - val_AUC: 0.7583 - val_accuracy: 0.7335 - val_loss: 1.2450 - learning_rate: 1.0000e-04
# Epoch 26/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9969 - accuracy: 0.9771 - loss: 0.3087 - val_AUC: 0.7450 - val_accuracy: 0.7656 - val_loss: 1.3761 - learning_rate: 1.0000e-04
# Epoch 27/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9980 - accuracy: 0.9803 - loss: 0.2883 - val_AUC: 0.7512 - val_accuracy: 0.7618 - val_loss: 1.4020 - learning_rate: 1.0000e-04
# Epoch 28/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - AUC: 0.9987 - accuracy: 0.9855 - loss: 0.2661 - val_AUC: 0.7502 - val_accuracy: 0.7543 - val_loss: 1.5115 - learning_rate: 1.0000e-04
# Epoch 29/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9991 - accuracy: 0.9933 - loss: 0.2408 - val_AUC: 0.7448 - val_accuracy: 0.7561 - val_loss: 1.7733 - learning_rate: 5.0000e-05
# Epoch 30/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - AUC: 0.9999 - accuracy: 0.9970 - loss: 0.2225 - val_AUC: 0.7371 - val_accuracy: 0.7486 - val_loss: 1.8808 - learning_rate: 5.0000e-05
# Epoch 31/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 1.0000 - accuracy: 0.9993 - loss: 0.2097 - val_AUC: 0.7328 - val_accuracy: 0.7543 - val_loss: 1.9518 - learning_rate: 5.0000e-05
# Epoch 32/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 1.0000 - accuracy: 0.9971 - loss: 0.2047 - val_AUC: 0.7251 - val_accuracy: 0.7259 - val_loss: 2.0255 - learning_rate: 5.0000e-05
# Epoch 33/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9991 - accuracy: 0.9976 - loss: 0.2033 - val_AUC: 0.7263 - val_accuracy: 0.7353 - val_loss: 2.0335 - learning_rate: 2.5000e-05
# Epoch 34/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - AUC: 1.0000 - accuracy: 0.9988 - loss: 0.1916 - val_AUC: 0.7238 - val_accuracy: 0.7467 - val_loss: 2.0816 - learning_rate: 2.5000e-05
# Epoch 35/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 1.0000 - accuracy: 0.9994 - loss: 0.1870 - val_AUC: 0.7293 - val_accuracy: 0.7316 - val_loss: 2.1830 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
#
# Fold 5 - {'accuracy_scores': 0.7563636363636363, 'recall_scores': 0.5741239892183289, 'precision_scores': 0.5461538461538461, 'f1_scores': 0.5597897503285151, 'specificity_scores': 0.8237051792828686, 'roc_auc_scores': 0.7852390975182827, 'conf_matrix': array([[827, 177],
#        [158, 213]])}
#
#  0.7852390975182827
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 6...
# Class weights:  {0: 0.669607996251757, 1: 1.9739871086556169}
# Epoch 1/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - AUC: 0.5188 - accuracy: 0.5266 - loss: 3.4789 - val_AUC: 0.5494 - val_accuracy: 0.6141 - val_loss: 2.8956 - learning_rate: 2.0000e-04
# Epoch 2/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.5014 - accuracy: 0.4966 - loss: 2.9057 - val_AUC: 0.4700 - val_accuracy: 0.4810 - val_loss: 2.6698 - learning_rate: 2.0000e-04
# Epoch 3/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - AUC: 0.5039 - accuracy: 0.5012 - loss: 2.6483 - val_AUC: 0.5840 - val_accuracy: 0.4886 - val_loss: 2.4501 - learning_rate: 2.0000e-04
# Epoch 4/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.5507 - accuracy: 0.5393 - loss: 2.4021 - val_AUC: 0.7081 - val_accuracy: 0.5837 - val_loss: 2.2184 - learning_rate: 2.0000e-04
# Epoch 5/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.6193 - accuracy: 0.5714 - loss: 2.1641 - val_AUC: 0.7153 - val_accuracy: 0.6502 - val_loss: 1.9658 - learning_rate: 2.0000e-04
# Epoch 6/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.7273 - accuracy: 0.6507 - loss: 1.8999 - val_AUC: 0.7384 - val_accuracy: 0.7129 - val_loss: 1.7314 - learning_rate: 2.0000e-04
# Epoch 7/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.7486 - accuracy: 0.6723 - loss: 1.7081 - val_AUC: 0.7487 - val_accuracy: 0.7129 - val_loss: 1.5674 - learning_rate: 2.0000e-04
# Epoch 8/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.7748 - accuracy: 0.7042 - loss: 1.5260 - val_AUC: 0.7567 - val_accuracy: 0.6578 - val_loss: 1.4546 - learning_rate: 2.0000e-04
# Epoch 9/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.7954 - accuracy: 0.7222 - loss: 1.3876 - val_AUC: 0.7656 - val_accuracy: 0.6863 - val_loss: 1.3182 - learning_rate: 2.0000e-04
# Epoch 10/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.8200 - accuracy: 0.7470 - loss: 1.2387 - val_AUC: 0.7661 - val_accuracy: 0.7091 - val_loss: 1.1953 - learning_rate: 2.0000e-04
# Epoch 11/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - AUC: 0.8299 - accuracy: 0.7548 - loss: 1.1363 - val_AUC: 0.7709 - val_accuracy: 0.7072 - val_loss: 1.1255 - learning_rate: 2.0000e-04
# Epoch 12/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - AUC: 0.8321 - accuracy: 0.7704 - loss: 1.0497 - val_AUC: 0.7710 - val_accuracy: 0.7186 - val_loss: 1.0326 - learning_rate: 2.0000e-04
# Epoch 13/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8420 - accuracy: 0.7730 - loss: 0.9687 - val_AUC: 0.7709 - val_accuracy: 0.6863 - val_loss: 1.0027 - learning_rate: 2.0000e-04
# Epoch 14/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8631 - accuracy: 0.7878 - loss: 0.8909 - val_AUC: 0.7709 - val_accuracy: 0.6958 - val_loss: 0.9347 - learning_rate: 2.0000e-04
# Epoch 15/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8727 - accuracy: 0.7952 - loss: 0.8292 - val_AUC: 0.7847 - val_accuracy: 0.6749 - val_loss: 0.9197 - learning_rate: 2.0000e-04
# Epoch 16/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8839 - accuracy: 0.8101 - loss: 0.7738 - val_AUC: 0.7799 - val_accuracy: 0.6730 - val_loss: 0.8905 - learning_rate: 2.0000e-04
# Epoch 17/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.8956 - accuracy: 0.8198 - loss: 0.7279 - val_AUC: 0.7597 - val_accuracy: 0.7357 - val_loss: 0.8174 - learning_rate: 2.0000e-04
# Epoch 18/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9075 - accuracy: 0.8295 - loss: 0.6849 - val_AUC: 0.7649 - val_accuracy: 0.6939 - val_loss: 0.8488 - learning_rate: 2.0000e-04
# Epoch 19/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.9188 - accuracy: 0.8361 - loss: 0.6482 - val_AUC: 0.7653 - val_accuracy: 0.6540 - val_loss: 0.8836 - learning_rate: 2.0000e-04
# Epoch 20/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9240 - accuracy: 0.8484 - loss: 0.6272 - val_AUC: 0.7727 - val_accuracy: 0.7224 - val_loss: 0.7953 - learning_rate: 2.0000e-04
# Epoch 21/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9373 - accuracy: 0.8694 - loss: 0.5869 - val_AUC: 0.7727 - val_accuracy: 0.7091 - val_loss: 0.8066 - learning_rate: 2.0000e-04
# Epoch 22/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9464 - accuracy: 0.8721 - loss: 0.5532 - val_AUC: 0.7676 - val_accuracy: 0.6730 - val_loss: 0.8568 - learning_rate: 2.0000e-04
# Epoch 23/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9546 - accuracy: 0.8759 - loss: 0.5202 - val_AUC: 0.7790 - val_accuracy: 0.7110 - val_loss: 0.8653 - learning_rate: 2.0000e-04
# Epoch 24/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9684 - accuracy: 0.9072 - loss: 0.4723 - val_AUC: 0.7479 - val_accuracy: 0.7091 - val_loss: 0.8964 - learning_rate: 2.0000e-04
# Epoch 25/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9869 - accuracy: 0.9398 - loss: 0.3939 - val_AUC: 0.7539 - val_accuracy: 0.7053 - val_loss: 1.0507 - learning_rate: 1.0000e-04
# Epoch 26/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9938 - accuracy: 0.9635 - loss: 0.3286 - val_AUC: 0.7269 - val_accuracy: 0.7224 - val_loss: 1.1754 - learning_rate: 1.0000e-04
# Epoch 27/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.9964 - accuracy: 0.9711 - loss: 0.2984 - val_AUC: 0.6990 - val_accuracy: 0.7300 - val_loss: 1.4539 - learning_rate: 1.0000e-04
# Epoch 28/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.9962 - accuracy: 0.9723 - loss: 0.2890 - val_AUC: 0.7187 - val_accuracy: 0.7281 - val_loss: 1.4103 - learning_rate: 1.0000e-04
# Epoch 29/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - AUC: 0.9993 - accuracy: 0.9883 - loss: 0.2442 - val_AUC: 0.7154 - val_accuracy: 0.7433 - val_loss: 1.5598 - learning_rate: 5.0000e-05
# Epoch 30/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9998 - accuracy: 0.9946 - loss: 0.2238 - val_AUC: 0.7098 - val_accuracy: 0.7338 - val_loss: 1.8270 - learning_rate: 5.0000e-05
# Epoch 31/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9993 - accuracy: 0.9926 - loss: 0.2207 - val_AUC: 0.7156 - val_accuracy: 0.7243 - val_loss: 1.7009 - learning_rate: 5.0000e-05
# Epoch 32/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.9998 - accuracy: 0.9942 - loss: 0.2075 - val_AUC: 0.7074 - val_accuracy: 0.7357 - val_loss: 1.9337 - learning_rate: 5.0000e-05
# Epoch 33/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - AUC: 0.9997 - accuracy: 0.9960 - loss: 0.1997 - val_AUC: 0.7035 - val_accuracy: 0.7319 - val_loss: 2.0424 - learning_rate: 2.5000e-05
# Epoch 34/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 1.0000 - accuracy: 0.9990 - loss: 0.1887 - val_AUC: 0.6976 - val_accuracy: 0.7452 - val_loss: 2.1174 - learning_rate: 2.5000e-05
# Epoch 35/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.9981 - accuracy: 0.9989 - loss: 0.1846 - val_AUC: 0.6970 - val_accuracy: 0.7471 - val_loss: 2.1849 - learning_rate: 2.5000e-05
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
#
# Fold 6 - {'accuracy_scores': 0.7204066811909949, 'recall_scores': 0.7835820895522388, 'precision_scores': 0.5138662316476346, 'f1_scores': 0.6206896551724138, 'specificity_scores': 0.6943589743589743, 'roc_auc_scores': 0.8222604924097462, 'conf_matrix': array([[677, 298],
#        [ 87, 315]])}
#
#  0.8222604924097462
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 7...
# Class weights:  {0: 0.6715425531914894, 1: 1.9573643410852712}
# Epoch 1/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - AUC: 0.4984 - accuracy: 0.5097 - loss: 3.4679 - val_AUC: 0.5085 - val_accuracy: 0.4425 - val_loss: 2.8939 - learning_rate: 2.0000e-04
# Epoch 2/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 29s 48ms/step - AUC: 0.4907 - accuracy: 0.4924 - loss: 2.9204 - val_AUC: 0.4886 - val_accuracy: 0.4770 - val_loss: 2.6548 - learning_rate: 2.0000e-04
# Epoch 3/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - AUC: 0.5099 - accuracy: 0.4872 - loss: 2.6339 - val_AUC: 0.5148 - val_accuracy: 0.4943 - val_loss: 2.4262 - learning_rate: 2.0000e-04
# Epoch 4/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 19s 47ms/step - AUC: 0.4941 - accuracy: 0.4919 - loss: 2.4070 - val_AUC: 0.5447 - val_accuracy: 0.4368 - val_loss: 2.2114 - learning_rate: 2.0000e-04
# Epoch 5/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - AUC: 0.5151 - accuracy: 0.5058 - loss: 2.1725 - val_AUC: 0.5793 - val_accuracy: 0.5670 - val_loss: 1.9964 - learning_rate: 2.0000e-04
# Epoch 6/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - AUC: 0.5429 - accuracy: 0.5129 - loss: 1.9714 - val_AUC: 0.6446 - val_accuracy: 0.6801 - val_loss: 1.7973 - learning_rate: 2.0000e-04
# Epoch 7/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 0.5805 - accuracy: 0.5699 - loss: 1.7677 - val_AUC: 0.7018 - val_accuracy: 0.6724 - val_loss: 1.6124 - learning_rate: 2.0000e-04
# Epoch 8/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.7067 - accuracy: 0.6694 - loss: 1.5613 - val_AUC: 0.7253 - val_accuracy: 0.7146 - val_loss: 1.4162 - learning_rate: 2.0000e-04
# Epoch 9/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.7459 - accuracy: 0.7140 - loss: 1.3960 - val_AUC: 0.7299 - val_accuracy: 0.6782 - val_loss: 1.3368 - learning_rate: 2.0000e-04
# Epoch 10/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.7771 - accuracy: 0.7242 - loss: 1.2708 - val_AUC: 0.7472 - val_accuracy: 0.6743 - val_loss: 1.2559 - learning_rate: 2.0000e-04
# Epoch 11/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.7932 - accuracy: 0.7258 - loss: 1.1712 - val_AUC: 0.7571 - val_accuracy: 0.7280 - val_loss: 1.1087 - learning_rate: 2.0000e-04
# Epoch 12/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - AUC: 0.8204 - accuracy: 0.7607 - loss: 1.0611 - val_AUC: 0.7717 - val_accuracy: 0.7146 - val_loss: 1.0402 - learning_rate: 2.0000e-04
# Epoch 13/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8498 - accuracy: 0.7850 - loss: 0.9536 - val_AUC: 0.7851 - val_accuracy: 0.7414 - val_loss: 0.9564 - learning_rate: 2.0000e-04
# Epoch 14/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8473 - accuracy: 0.7799 - loss: 0.9119 - val_AUC: 0.7851 - val_accuracy: 0.7088 - val_loss: 0.9365 - learning_rate: 2.0000e-04
# Epoch 15/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8707 - accuracy: 0.7976 - loss: 0.8263 - val_AUC: 0.7892 - val_accuracy: 0.7107 - val_loss: 0.8914 - learning_rate: 2.0000e-04
# Epoch 16/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8762 - accuracy: 0.7996 - loss: 0.7894 - val_AUC: 0.7745 - val_accuracy: 0.6801 - val_loss: 0.9203 - learning_rate: 2.0000e-04
# Epoch 17/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8926 - accuracy: 0.8103 - loss: 0.7318 - val_AUC: 0.7818 - val_accuracy: 0.7375 - val_loss: 0.8308 - learning_rate: 2.0000e-04
# Epoch 18/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8978 - accuracy: 0.8209 - loss: 0.7082 - val_AUC: 0.7915 - val_accuracy: 0.7184 - val_loss: 0.8151 - learning_rate: 2.0000e-04
# Epoch 19/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9139 - accuracy: 0.8355 - loss: 0.6496 - val_AUC: 0.7827 - val_accuracy: 0.6992 - val_loss: 0.8193 - learning_rate: 2.0000e-04
# Epoch 20/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9305 - accuracy: 0.8481 - loss: 0.6032 - val_AUC: 0.7692 - val_accuracy: 0.7222 - val_loss: 0.8339 - learning_rate: 2.0000e-04
# Epoch 21/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9387 - accuracy: 0.8623 - loss: 0.5743 - val_AUC: 0.7712 - val_accuracy: 0.7165 - val_loss: 0.8807 - learning_rate: 2.0000e-04
# Epoch 22/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9556 - accuracy: 0.8808 - loss: 0.5206 - val_AUC: 0.7676 - val_accuracy: 0.7280 - val_loss: 0.8958 - learning_rate: 2.0000e-04
# Epoch 23/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9760 - accuracy: 0.9194 - loss: 0.4405 - val_AUC: 0.7723 - val_accuracy: 0.7395 - val_loss: 1.0045 - learning_rate: 1.0000e-04
# Epoch 24/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - AUC: 0.9896 - accuracy: 0.9531 - loss: 0.3593 - val_AUC: 0.7481 - val_accuracy: 0.7452 - val_loss: 1.2061 - learning_rate: 1.0000e-04
# Epoch 25/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9940 - accuracy: 0.9639 - loss: 0.3191 - val_AUC: 0.7580 - val_accuracy: 0.7395 - val_loss: 1.2555 - learning_rate: 1.0000e-04
# Epoch 26/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.9944 - accuracy: 0.9756 - loss: 0.2870 - val_AUC: 0.7571 - val_accuracy: 0.7414 - val_loss: 1.2896 - learning_rate: 1.0000e-04
# Epoch 27/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.9983 - accuracy: 0.9865 - loss: 0.2563 - val_AUC: 0.7408 - val_accuracy: 0.7318 - val_loss: 1.6003 - learning_rate: 5.0000e-05
# Epoch 28/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.9997 - accuracy: 0.9950 - loss: 0.2274 - val_AUC: 0.7213 - val_accuracy: 0.7318 - val_loss: 1.8632 - learning_rate: 5.0000e-05
# Epoch 29/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.9999 - accuracy: 0.9942 - loss: 0.2139 - val_AUC: 0.7262 - val_accuracy: 0.7414 - val_loss: 1.9481 - learning_rate: 5.0000e-05
# Epoch 30/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9999 - accuracy: 0.9967 - loss: 0.2022 - val_AUC: 0.7349 - val_accuracy: 0.7682 - val_loss: 1.9797 - learning_rate: 5.0000e-05
# Epoch 31/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.9999 - accuracy: 0.9973 - loss: 0.1957 - val_AUC: 0.7360 - val_accuracy: 0.7433 - val_loss: 2.0630 - learning_rate: 2.5000e-05
# Epoch 32/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 1.0000 - accuracy: 0.9982 - loss: 0.1891 - val_AUC: 0.7377 - val_accuracy: 0.7375 - val_loss: 2.1091 - learning_rate: 2.5000e-05
# Epoch 33/60
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 1.0000 - accuracy: 0.9992 - loss: 0.1834 - val_AUC: 0.7260 - val_accuracy: 0.7375 - val_loss: 2.2148 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
#
# Fold 7 - {'accuracy_scores': 0.7170909090909091, 'recall_scores': 0.864, 'precision_scores': 0.48942598187311176, 'f1_scores': 0.6248794599807136, 'specificity_scores': 0.662, 'roc_auc_scores': 0.8402853333333333, 'conf_matrix': array([[662, 338],
#        [ 51, 324]])}
#
#  0.8402853333333333
# 382, 48, 61, participants in Train, Validation, and Test sets
# Processing fold 8...
# Class weights:  {0: 0.6748345414434289, 1: 1.9299233889139251}
# Epoch 1/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - AUC: 0.5135 - accuracy: 0.5200 - loss: 3.5105 - val_AUC: 0.5281 - val_accuracy: 0.4850 - val_loss: 2.9154 - learning_rate: 2.0000e-04
# Epoch 2/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.5184 - accuracy: 0.5150 - loss: 2.9088 - val_AUC: 0.5546 - val_accuracy: 0.4192 - val_loss: 2.6982 - learning_rate: 2.0000e-04
# Epoch 3/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.5232 - accuracy: 0.5309 - loss: 2.6666 - val_AUC: 0.6562 - val_accuracy: 0.5451 - val_loss: 2.4575 - learning_rate: 2.0000e-04
# Epoch 4/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - AUC: 0.5937 - accuracy: 0.5512 - loss: 2.4084 - val_AUC: 0.7170 - val_accuracy: 0.6391 - val_loss: 2.2135 - learning_rate: 2.0000e-04
# Epoch 5/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.6929 - accuracy: 0.6484 - loss: 2.1323 - val_AUC: 0.7301 - val_accuracy: 0.7068 - val_loss: 1.9659 - learning_rate: 2.0000e-04
# Epoch 6/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.7329 - accuracy: 0.6751 - loss: 1.9122 - val_AUC: 0.7740 - val_accuracy: 0.7162 - val_loss: 1.7326 - learning_rate: 2.0000e-04
# Epoch 7/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - AUC: 0.7715 - accuracy: 0.6960 - loss: 1.6936 - val_AUC: 0.7883 - val_accuracy: 0.7312 - val_loss: 1.5543 - learning_rate: 2.0000e-04
# Epoch 8/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - AUC: 0.7935 - accuracy: 0.7345 - loss: 1.5182 - val_AUC: 0.7875 - val_accuracy: 0.7218 - val_loss: 1.4180 - learning_rate: 2.0000e-04
# Epoch 9/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.8242 - accuracy: 0.7606 - loss: 1.3405 - val_AUC: 0.8007 - val_accuracy: 0.7406 - val_loss: 1.2843 - learning_rate: 2.0000e-04
# Epoch 10/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - AUC: 0.8204 - accuracy: 0.7526 - loss: 1.2284 - val_AUC: 0.7825 - val_accuracy: 0.7406 - val_loss: 1.1709 - learning_rate: 2.0000e-04
# Epoch 11/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8420 - accuracy: 0.7668 - loss: 1.1156 - val_AUC: 0.7781 - val_accuracy: 0.7237 - val_loss: 1.0907 - learning_rate: 2.0000e-04
# Epoch 12/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8576 - accuracy: 0.7827 - loss: 1.0134 - val_AUC: 0.7883 - val_accuracy: 0.7274 - val_loss: 1.0058 - learning_rate: 2.0000e-04
# Epoch 13/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8761 - accuracy: 0.7934 - loss: 0.9214 - val_AUC: 0.7969 - val_accuracy: 0.6917 - val_loss: 0.9842 - learning_rate: 2.0000e-04
# Epoch 14/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8812 - accuracy: 0.8047 - loss: 0.8548 - val_AUC: 0.8029 - val_accuracy: 0.6917 - val_loss: 0.9666 - learning_rate: 2.0000e-04
# Epoch 15/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.8952 - accuracy: 0.8086 - loss: 0.8005 - val_AUC: 0.7748 - val_accuracy: 0.7312 - val_loss: 0.8868 - learning_rate: 2.0000e-04
# Epoch 16/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9033 - accuracy: 0.8246 - loss: 0.7570 - val_AUC: 0.7834 - val_accuracy: 0.7199 - val_loss: 0.8499 - learning_rate: 2.0000e-04
# Epoch 17/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.9163 - accuracy: 0.8402 - loss: 0.7015 - val_AUC: 0.7781 - val_accuracy: 0.6729 - val_loss: 0.9071 - learning_rate: 2.0000e-04
# Epoch 18/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9222 - accuracy: 0.8335 - loss: 0.6717 - val_AUC: 0.7555 - val_accuracy: 0.7049 - val_loss: 0.8606 - learning_rate: 2.0000e-04
# Epoch 19/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.9388 - accuracy: 0.8641 - loss: 0.6218 - val_AUC: 0.7579 - val_accuracy: 0.7068 - val_loss: 0.8747 - learning_rate: 2.0000e-04
# Epoch 20/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - AUC: 0.9499 - accuracy: 0.8796 - loss: 0.5798 - val_AUC: 0.7572 - val_accuracy: 0.7387 - val_loss: 0.8718 - learning_rate: 2.0000e-04
# Epoch 21/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - AUC: 0.9713 - accuracy: 0.9078 - loss: 0.5054 - val_AUC: 0.7681 - val_accuracy: 0.6767 - val_loss: 0.9612 - learning_rate: 1.0000e-04
# Epoch 22/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9845 - accuracy: 0.9383 - loss: 0.4326 - val_AUC: 0.7563 - val_accuracy: 0.7256 - val_loss: 0.9825 - learning_rate: 1.0000e-04
# Epoch 23/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9883 - accuracy: 0.9509 - loss: 0.3868 - val_AUC: 0.7387 - val_accuracy: 0.7237 - val_loss: 1.1658 - learning_rate: 1.0000e-04
# Epoch 24/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9924 - accuracy: 0.9612 - loss: 0.3593 - val_AUC: 0.7724 - val_accuracy: 0.7124 - val_loss: 1.0897 - learning_rate: 1.0000e-04
# Epoch 25/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9951 - accuracy: 0.9735 - loss: 0.3252 - val_AUC: 0.7428 - val_accuracy: 0.7387 - val_loss: 1.2993 - learning_rate: 5.0000e-05
# Epoch 26/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9989 - accuracy: 0.9859 - loss: 0.2825 - val_AUC: 0.7189 - val_accuracy: 0.7162 - val_loss: 1.5403 - learning_rate: 5.0000e-05
# Epoch 27/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9992 - accuracy: 0.9882 - loss: 0.2661 - val_AUC: 0.7338 - val_accuracy: 0.7368 - val_loss: 1.5307 - learning_rate: 5.0000e-05
# Epoch 28/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9997 - accuracy: 0.9924 - loss: 0.2501 - val_AUC: 0.7145 - val_accuracy: 0.7218 - val_loss: 1.6557 - learning_rate: 5.0000e-05
# Epoch 29/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9998 - accuracy: 0.9950 - loss: 0.2390 - val_AUC: 0.6990 - val_accuracy: 0.7350 - val_loss: 1.8561 - learning_rate: 2.5000e-05
# Epoch 30/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - AUC: 0.9996 - accuracy: 0.9971 - loss: 0.2306 - val_AUC: 0.7118 - val_accuracy: 0.7331 - val_loss: 1.9244 - learning_rate: 2.5000e-05
# Epoch 31/60
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - AUC: 0.9999 - accuracy: 0.9965 - loss: 0.2262 - val_AUC: 0.7106 - val_accuracy: 0.7331 - val_loss: 1.9303 - learning_rate: 2.5000e-05
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
#
# Fold 8 - {'accuracy_scores': 0.7134545454545455, 'recall_scores': 0.786096256684492, 'precision_scores': 0.48355263157894735, 'f1_scores': 0.5987780040733197, 'specificity_scores': 0.6863136863136863, 'roc_auc_scores': 0.8168302285949346, 'conf_matrix': array([[687, 314],
#        [ 80, 294]])}
#
#  0.8168302285949346
#
# Average Test Accuracy: 0.7288 (+- 0.0239)
# Average Test Recall: 0.7293 (+- 0.0878)
# Average Test Specificity: 0.7269 (+- 0.0582)
# Average Test AUC: 0.8064 (+- 0.0199)
# Aggregated Models on Pediatric set ...
#
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# Target Accuracy: 0.7438
# Target Recall: 0.7229
# Target Specificity: 0.7502
# Target ROC AUC: 0.8026
# Plot saved at: /home/ma98/results/holdoutResultsFull/NightMorning1/loss_auc_accuracy_plot.png
